# %%
import networkx as nx
from more_itertools import flatten
from entity.taxonomy import Taxonomy

combined_taxonomy = Taxonomy('combined-filtered').load('../data/interim/mixed_gitranking_cso_wikidata.json')

# %%
len(set(flatten(combined_taxonomy.pairs)))
# Out:
# 1027

# %%
import pandas as pd

llm_ad = pd.read_csv('../data/interim/llm_responses_is_ad.csv')
llm_ad = llm_ad[llm_ad['response'] == '0']

# %%
llm_ad
# Out:
#                     term response
# 0               noticing        0
# 1      physical property        0
# 3              reasoning        0
# 4          effectiveness        0
# 7      learning material        0
# ...                  ...      ...
# 1277         infographic        0
# 1278    physical process        0
# 1280     economic entity        0
# 1281  physical container        0
# 1283               union        0
#
# [744 rows x 2 columns]

# %%
filtered_pairs = []
remaining_pairs = []
for pair in combined_taxonomy.pairs:
    if any(term in llm_ad['term'].values for term in [pair[0], pair[1]]):
        filtered_pairs.append(pair)
    else:
        remaining_pairs.append(pair)
        
print(len(filtered_pairs), len(combined_taxonomy.pairs))
# Out:
# 1166 1715

# %%
filtered_pairs
# Out:
# [['curricula', 'education', 'cso'],
#  ['peer-to-peer', 'distributed computer systems', 'cso'],
#  ['network analysis', 'electric network analysis', 'cso'],
#  ['natural languages', 'semantics', 'cso'],
#  ['probability', 'mathematics', 'cso'],
#  ['smart homes', 'smart environment', 'cso'],
#  ['visualization', 'human computer interaction', 'cso'],
#  ['natural sciences computing', 'database systems', 'cso'],
#  ['mobile computing', 'telecommunication networks', 'cso'],
#  ['data visualization', 'visualization', 'cso'],
#  ['man machine systems', 'robotics', 'cso'],
#  ['speech transmission', 'speech communication', 'cso'],
#  ['image compression', 'image coding', 'cso'],
#  ['security of data', 'computer security', 'cso'],
#  ['frequency division multiple access', 'frequency allocation', 'cso'],
#  ['wireless telecommunication systems', 'communication systems', 'cso'],
#  ['computer science education', 'curricula', 'cso'],
#  ['frequency allocation', 'communication channels', 'cso'],
#  ['cloud services', 'mobile devices', 'cso'],
#  ['distributed database systems', 'data communication systems', 'cso'],
#  ['servers', 'security of data', 'cso'],
#  ['speech transmission', 'natural language processing', 'cso'],
#  ['synthesized speech', 'speech communication', 'cso'],
#  ['electronic mail', 'internet', 'cso'],
#  ['signal processing', 'engineering', 'cso'],
#  ['smart environment', 'ambient intelligence', 'cso'],
#  ['internet', 'computer science', 'cso'],
#  ['information theory', 'communication', 'cso'],
#  ['ebusiness', 'information technology', 'cso'],
#  ['manifold learning', 'dimensionality reduction', 'cso'],
#  ['fuzzy time series', 'forecasting models', 'cso'],
#  ['wireless telecommunication systems', 'telecommunication systems', 'cso'],
#  ['big data', 'digital storage', 'cso'],
#  ['digital watermarking', 'security of data', 'cso'],
#  ['communication channels', 'wireless telecommunication systems', 'cso'],
#  ['motion estimation', 'image coding', 'cso'],
#  ['data augmentation', 'bayesian analysis', 'cso'],
#  ['packet networks', 'telecommunication traffic', 'cso'],
#  ['signal theory', 'matrix algebra', 'cso'],
#  ['functional languages', 'linguistics', 'cso'],
#  ['blockchain', 'peer-to-peer', 'cso'],
#  ['microprocessor chips', 'computer hardware', 'cso'],
#  ['malwares', 'computer crime', 'cso'],
#  ['routing protocols', 'wireless telecommunication systems', 'cso'],
#  ['telecommunication networks', 'telecommunication systems', 'cso'],
#  ['routers', 'telecommunication traffic', 'cso'],
#  ['autonomous vehicles', 'vehicles', 'cso'],
#  ['data communication systems', 'computer systems', 'cso'],
#  ['image coding', 'image processing', 'cso'],
#  ['quality of service', 'bandwidth', 'cso'],
#  ['imaging systems', 'image reconstruction', 'cso'],
#  ['information visualization', 'information analysis', 'cso'],
#  ['cryptology', 'computer security', 'cso'],
#  ['manifold learning', 'face recognition', 'cso'],
#  ['natural sciences computing', 'parallel processing systems', 'cso'],
#  ['stream processing', 'data communication systems', 'cso'],
#  ['world wide web', 'internet', 'cso'],
#  ['servers', 'world wide web', 'cso'],
#  ['search engines', 'world wide web', 'cso'],
#  ['local geometry', 'manifold learning', 'cso'],
#  ['spurious signal noise', 'communication channels', 'cso'],
#  ['web application', 'world wide web', 'cso'],
#  ['automation', 'engineering', 'cso'],
#  ['identity based cryptography', 'identity-based', 'cso'],
#  ['directed graphs', 'graph theory', 'cso'],
#  ['social networks', 'world wide web', 'cso'],
#  ['reverse engineering', 'architecting', 'cso'],
#  ['cryptography', 'cryptology', 'cso'],
#  ['speech transmission', 'translation %28languages%29', 'cso'],
#  ['image quality', 'image analysis', 'cso'],
#  ['field programmable gate array', 'computer hardware', 'cso'],
#  ['bayes theorem', 'probability', 'cso'],
#  ['quality of service', 'telecommunication traffic', 'cso'],
#  ['communication networks', 'telecommunication networks', 'cso'],
#  ['discriminant analysis', 'probability', 'cso'],
#  ['cloud services', 'communication', 'cso'],
#  ['forecasting models', 'machine learning', 'cso'],
#  ['phishing', 'world wide web', 'cso'],
#  ['information security', 'security of data', 'cso'],
#  ['identity-based', 'electronic document identification systems', 'cso'],
#  ['man machine systems', 'human engineering', 'cso'],
#  ['cryptocurrency', 'blockchain', 'cso'],
#  ['multimedia systems', 'internet', 'cso'],
#  ['data analytics', 'big data', 'cso'],
#  ['optimization problems', 'correlation analysis', 'cso'],
#  ['mobile telecommunication systems', 'telecommunication networks', 'cso'],
#  ['markov processes', 'correlation analysis', 'cso'],
#  ['image compression', 'image quality', 'cso'],
#  ['packet scheduling', 'quality of service', 'cso'],
#  ['identity-based', 'public key cryptography', 'cso'],
#  ['client server computer systems', 'database systems', 'cso'],
#  ['continuous speech recognition', 'speech communication', 'cso'],
#  ['bayesian analysis', 'bayes theorem', 'cso'],
#  ['static analysis', 'software engineering', 'cso'],
#  ['graph algorithms', 'graph theory', 'cso'],
#  ['autonomous vehicles', 'motion planning', 'cso'],
#  ['signal theory', 'spurious signal noise', 'cso'],
#  ['3d objects', 'three dimensional computer graphics', 'cso'],
#  ['vehicles', 'engineering', 'cso'],
#  ['devops', 'software development', 'cso'],
#  ['dijkstras algorithms', 'routing algorithms', 'cso'],
#  ['information analysis', 'database systems', 'cso'],
#  ['target language', 'machine translations', 'cso'],
#  ['bayesian inference', 'bayes theorem', 'cso'],
#  ['intrusion detection', 'computer crime', 'cso'],
#  ['information management', 'information technology', 'cso'],
#  ['spurious signal noise', 'signal to noise ratio', 'cso'],
#  ['static analysis', 'program compilers', 'cso'],
#  ['email', 'electronic mail', 'cso'],
#  ['q-learning', 'reinforcement learning', 'cso'],
#  ['stock market', 'commerce', 'cso'],
#  ['optical resolving power', 'image quality', 'cso'],
#  ['program interpreters', 'linguistics', 'cso'],
#  ['mobile applications', 'mobile devices', 'cso'],
#  ['man machine systems', 'cognitive systems', 'cso'],
#  ['web application security', 'sql injection', 'cso'],
#  ['bayes theorem', 'correlation analysis', 'cso'],
#  ['computer crime', 'security of data', 'cso'],
#  ['peer-to-peer', 'internet', 'cso'],
#  ['architecting', 'software architecture', 'cso'],
#  ['semi-supervised clustering', 'clustering algorithms', 'cso'],
#  ['packet scheduling', 'packet networks', 'cso'],
#  ['client server computer systems', 'data communication systems', 'cso'],
#  ['peer-to-peer', 'computer networks', 'cso'],
#  ['mobile computing', 'data communication systems', 'cso'],
#  ['malwares', 'network security', 'cso'],
#  ['client server computer systems', 'telecommunication traffic', 'cso'],
#  ['target language', 'speech transmission', 'cso'],
#  ['speech transmission', 'information theory', 'cso'],
#  ['client server computer systems', 'user interfaces', 'cso'],
#  ['3d graphics', 'visualization', 'cso'],
#  ['computer hardware', 'computer science', 'cso'],
#  ['sql injection', 'web application', 'cso'],
#  ['phishing', 'electronic mail', 'cso'],
#  ['commerce', 'economics', 'cso'],
#  ['routing protocols', 'routers', 'cso'],
#  ['mobile computing', 'wireless telecommunication systems', 'cso'],
#  ['local geometry', 'geometry', 'cso'],
#  ['digital storage', 'computer hardware', 'cso'],
#  ['digital libraries', 'world wide web', 'cso'],
#  ['cloud services', 'commerce', 'cso'],
#  ['correlation analysis', 'mathematics', 'cso'],
#  ['random forests', 'decision trees', 'cso'],
#  ['information technology', 'computer science', 'cso'],
#  ['man machine systems', 'user interfaces', 'cso'],
#  ['display devices', 'user interfaces', 'cso'],
#  ['collaborative virtual environment', 'display devices', 'cso'],
#  ['optical resolving power', 'image reconstruction', 'cso'],
#  ['scientific computing', 'natural sciences computing', 'cso'],
#  ['client server computer systems', 'distributed computer systems', 'cso'],
#  ['embedded processors', 'field programmable gate array', 'cso'],
#  ['programming course', 'computer science education', 'cso'],
#  ['mobile devices', 'mobile computing', 'cso'],
#  ['source language', 'target language', 'cso'],
#  ['natural languages', 'linguistics', 'cso'],
#  ['autonomous vehicles', 'computer vision', 'cso'],
#  ['natural language processing', 'natural languages', 'cso'],
#  ['bitcoin', 'cryptocurrency', 'cso'],
#  ['malware detection', 'malwares', 'cso'],
#  ['shortest path', 'graph theory', 'cso'],
#  ['network routing', 'routing protocols', 'cso'],
#  ['cellular network', 'wireless telecommunication systems', 'cso'],
#  ['telecommunication traffic', 'telecommunication networks', 'cso'],
#  ['graph theory', 'theoretical computer science', 'cso'],
#  ['sensors', 'computer hardware', 'cso'],
#  ['logistic regression models', 'logistic regression', 'cso'],
#  ['sql injection', 'computer crime', 'cso'],
#  ['mobile telecommunication systems', 'communication channels', 'cso'],
#  ['malwares', 'operating systems', 'cso'],
#  ['system level simulation', 'frequency division multiple access', 'cso'],
#  ['wireless telecommunication systems', 'computer networks', 'cso'],
#  ['matrix algebra', 'mathematics', 'cso'],
#  ['web content', 'world wide web', 'cso'],
#  ['web service discovery', 'world wide web', 'cso'],
#  ['client server computer systems', 'world wide web', 'cso'],
#  ['phishing', 'computer crime', 'cso'],
#  ['communication networks', 'communication', 'cso'],
#  ['human machine interface', 'man machine systems', 'cso'],
#  ['semantic web', 'world wide web', 'cso'],
#  ['speech communication', 'linguistics', 'cso'],
#  ['internet of things', 'internet', 'cso'],
#  ['client server computer systems', 'multimedia systems', 'cso'],
#  ['factorization', 'matrix algebra', 'cso'],
#  ['packet networks', 'wireless telecommunication systems', 'cso'],
#  ['electric network topology', 'telecommunication networks', 'cso'],
#  ['information extraction', 'information analysis', 'cso'],
#  ['routing algorithms', 'computer networks', 'cso'],
#  ['information analysis', 'information systems', 'cso'],
#  ['translation %28languages%29', 'linguistics', 'cso'],
#  ['image reconstruction', 'image processing', 'cso'],
#  ['frequency allocation', 'data communication systems', 'cso'],
#  ['sql injection', 'network security', 'cso'],
#  ['network management', 'telecommunication networks', 'cso'],
#  ['video streaming', 'image coding', 'cso'],
#  ['real time systems', 'field programmable gate array', 'cso'],
#  ['phishing attacks', 'phishing', 'cso'],
#  ['authentication', 'security of data', 'cso'],
#  ['frequency allocation', 'telecommunication traffic', 'cso'],
#  ['image quality', 'image processing', 'cso'],
#  ['natural language interfaces', 'natural languages', 'cso'],
#  ['online social networks', 'social networks', 'cso'],
#  ['image reconstruction', 'image analysis', 'cso'],
#  ['logistic regression', 'correlation analysis', 'cso'],
#  ['autonomous driving', 'autonomous vehicles', 'cso'],
#  ['skill', 'athletic performance', 'wikidata'],
#  ['participant', 'object', 'wikidata'],
#  ['methodology', 'analysis', 'wikidata'],
#  ['actor', 'participant', 'wikidata'],
#  ['process', 'temporal entity', 'wikidata'],
#  ['method', 'means', 'wikidata'],
#  ['means', 'cause', 'wikidata'],
#  ['series', 'class', 'wikidata'],
#  ['temporal entity', 'spatio-temporal entity', 'wikidata'],
#  ['class', 'collective entity', 'wikidata'],
#  ['athletic performance', 'effectiveness', 'wikidata'],
#  ['benchmarking', 'monitoring and evaluation', 'wikidata'],
#  ['analysis', 'inquiry', 'wikidata'],
#  ['computer benchmarking', 'benchmarking', 'wikidata'],
#  ['professional skill', 'aptitude', 'wikidata'],
#  ['human behavior', 'behavior', 'wikidata'],
#  ['scholarly method', 'method', 'wikidata'],
#  ['content', 'abstract entity', 'wikidata'],
#  ['memory', 'content', 'wikidata'],
#  ['quality control method', 'evaluation', 'wikidata'],
#  ['cause', 'source', 'wikidata'],
#  ['inquiry', 'seeking', 'wikidata'],
#  ['pattern', 'regularity', 'wikidata'],
#  ['process', 'occurrent', 'wikidata'],
#  ['professional skill', 'skill', 'wikidata'],
#  ['abstract entity', 'entity', 'wikidata'],
#  ['occurrent', 'entity', 'wikidata'],
#  ['seeking', 'activity', 'wikidata'],
#  ['collective entity', 'entity', 'wikidata'],
#  ['evaluation', 'assessment', 'wikidata'],
#  ['object', 'entity', 'wikidata'],
#  ['quality', 'property', 'wikidata'],
#  ['computer benchmarking', 'evaluation', 'wikidata'],
#  ['management tool', 'technique', 'wikidata'],
#  ['memory', 'information', 'wikidata'],
#  ['planned process', 'process', 'wikidata'],
#  ['effectiveness', 'quality', 'wikidata'],
#  ['planned process', 'intentional human activity', 'wikidata'],
#  ['intentional human activity', 'human behavior', 'wikidata'],
#  ['spatio-temporal entity', 'object', 'wikidata'],
#  ['process', 'series', 'wikidata'],
#  ['evaluation', 'process', 'wikidata'],
#  ['monitoring and evaluation', 'risk management tool', 'wikidata'],
#  ['property', 'abstract entity', 'wikidata'],
#  ['technique', 'method', 'wikidata'],
#  ['analysis', 'scholarly method', 'wikidata'],
#  ['assessment', 'process', 'wikidata'],
#  ['inquiry', 'planned process', 'wikidata'],
#  ['activity', 'process', 'wikidata'],
#  ['monitoring and evaluation', 'activity', 'wikidata'],
#  ['quality control method', 'methodology', 'wikidata'],
#  ['source', 'entity', 'wikidata'],
#  ['evaluation', 'method', 'wikidata'],
#  ['skill', 'knowledge', 'wikidata'],
#  ['monitoring and evaluation', 'quality control method', 'wikidata'],
#  ['computer benchmarking', 'professional skill', 'wikidata'],
#  ['quality control method', 'method', 'wikidata'],
#  ['behavior', 'pattern', 'wikidata'],
#  ['information', 'knowledge', 'wikidata'],
#  ['knowledge', 'memory', 'wikidata'],
#  ['regularity', 'abstract entity', 'wikidata'],
#  ['skill', 'aptitude', 'wikidata'],
#  ['aptitude', 'quality', 'wikidata'],
#  ['cause', 'actor', 'wikidata'],
#  ['work', 'cultural artifact', 'wikidata'],
#  ['cultural heritage', 'heritage', 'wikidata'],
#  ['rights', 'agreement', 'wikidata'],
#  ['resource', 'source', 'wikidata'],
#  ['linguistic unit', 'unit', 'wikidata'],
#  ['erga omnes', 'right', 'wikidata'],
#  ['unit', 'entity', 'wikidata'],
#  ['unit of speech', 'linguistic unit', 'wikidata'],
#  ['set', 'class', 'wikidata'],
#  ['mathematical structure', 'abstract structure', 'wikidata'],
#  ['relation', 'relation', 'wikidata'],
#  ['concept', 'semantic unit', 'wikidata'],
#  ['organization', 'person or organization', 'wikidata'],
#  ['heritage', 'object', 'wikidata'],
#  ['specifically dependent continuant', 'continuant', 'wikidata'],
#  ['relation', 'set', 'wikidata'],
#  ['property', 'goods', 'wikidata'],
#  ['science', 'knowledge system', 'wikidata'],
#  ['role', 'realizable entity', 'wikidata'],
#  ['scalar', 'antisymmetric tensor', 'wikidata'],
#  ['representation', 'artificial object', 'wikidata'],
#  ['unit of measurement', 'scalar quantity', 'wikidata'],
#  ['agent', 'continuant', 'wikidata'],
#  ['corporate body', 'agent', 'wikidata'],
#  ['work', 'artificial object', 'wikidata'],
#  ['system', 'collective entity', 'wikidata'],
#  ['person or organization', 'corporate body', 'wikidata'],
#  ['law', 'rule', 'wikidata'],
#  ['occurrence', 'temporal entity', 'wikidata'],
#  ['software', 'product', 'wikidata'],
#  ['right', 'rights and privileges', 'wikidata'],
#  ['humanities', 'social sciences and humanities', 'wikidata'],
#  ['intangible asset', 'asset', 'wikidata'],
#  ['semantic unit', 'constituent', 'wikidata'],
#  ['management', 'control', 'wikidata'],
#  ['management', 'coordination', 'wikidata'],
#  ['intellectual property', 'property', 'wikidata'],
#  ['abstract class', 'class', 'wikidata'],
#  ['goods', 'goods and services', 'wikidata'],
#  ['set', 'class', 'wikidata'],
#  ['coordination', 'activity', 'wikidata'],
#  ['consensus', 'state', 'wikidata'],
#  ['abstract structure', 'abstract entity', 'wikidata'],
#  ['message', 'information', 'wikidata'],
#  ['value', 'relation', 'wikidata'],
#  ['administration', 'organization', 'wikidata'],
#  ['artificial physical object', 'artificial object', 'wikidata'],
#  ['control', 'activity', 'wikidata'],
#  ['multivalued function', 'serial relation', 'wikidata'],
#  ['antisymmetric tensor', 'tensor', 'wikidata'],
#  ['concept', 'mental representation', 'wikidata'],
#  ['data type', 'type', 'wikidata'],
#  ['scalar', 'magnitude', 'wikidata'],
#  ['person or organization', 'agent', 'wikidata'],
#  ['concept', 'abstract entity', 'wikidata'],
#  ['corporate body', 'object', 'wikidata'],
#  ['function', 'multivalued function', 'wikidata'],
#  ['concept', 'aptitude', 'wikidata'],
#  ['mapping', 'assignment', 'wikidata'],
#  ['mathematical object', 'scientific object', 'wikidata'],
#  ['multiset', 'mathematical object', 'wikidata'],
#  ['goods and services', 'spatio-temporal entity', 'wikidata'],
#  ['value', 'mathematical object', 'wikidata'],
#  ['action', 'occurrence', 'wikidata'],
#  ['cultural artifact', 'cultural heritage', 'wikidata'],
#  ['class', 'mathematical structure', 'wikidata'],
#  ['administration', 'specialty', 'wikidata'],
#  ['unit of measurement', 'measure', 'wikidata'],
#  ['software', 'written work', 'wikidata'],
#  ['intellectual property', 'intangible asset', 'wikidata'],
#  ['legal concept', 'concept', 'wikidata'],
#  ['mathematical structure', 'mathematical object', 'wikidata'],
#  ['creative work', 'intellectual work', 'wikidata'],
#  ['serial relation', 'binary relation', 'wikidata'],
#  ['formalization', 'representation', 'wikidata'],
#  ['conceptual system', 'abstract entity', 'wikidata'],
#  ['quantity', 'value', 'wikidata'],
#  ['quantity', 'property', 'wikidata'],
#  ['intellectual work', 'work', 'wikidata'],
#  ['knowledge system', 'conceptual system', 'wikidata'],
#  ['rule', 'message', 'wikidata'],
#  ['intellectual work', 'intellectual property', 'wikidata'],
#  ['scientific object', 'object', 'wikidata'],
#  ['term', 'word or phrase', 'wikidata'],
#  ['phenomenon', 'observable entity', 'wikidata'],
#  ['right', 'rights', 'wikidata'],
#  ['function', 'binary relation', 'wikidata'],
#  ['multivalued function', 'function', 'wikidata'],
#  ['multilinear map', 'mapping', 'wikidata'],
#  ['assignment', 'action', 'wikidata'],
#  ['exclusive right', 'rights', 'wikidata'],
#  ['control', 'role', 'wikidata'],
#  ['physical quantity', 'physical property', 'wikidata'],
#  ['agreement', 'agreement', 'wikidata'],
#  ['resource', 'continuant', 'wikidata'],
#  ['knowledge type', 'type', 'wikidata'],
#  ['subject', 'continuant', 'wikidata'],
#  ['binary relation', 'relation', 'wikidata'],
#  ['function', 'partial function', 'wikidata'],
#  ['intellectual property', 'exclusive right', 'wikidata'],
#  ['specialty', 'knowledge system', 'wikidata'],
#  ['administration', 'humanities', 'wikidata'],
#  ['physico-chemical property', 'property', 'wikidata'],
#  ['physical property', 'physico-chemical property', 'wikidata'],
#  ['product', 'object', 'wikidata'],
#  ['artificial object', 'object', 'wikidata'],
#  ['partial function', 'function', 'wikidata'],
#  ['social sciences and humanities', 'science', 'wikidata'],
#  ['representation', 'sign', 'wikidata'],
#  ['organization', 'social system', 'wikidata'],
#  ['emic unit', 'linguistic unit', 'wikidata'],
#  ['consensus', 'occurrence', 'wikidata'],
#  ['scalar', 'symmetric tensor', 'wikidata'],
#  ['linguistic form', 'unit of speech', 'wikidata'],
#  ['specialty', 'knowledge', 'wikidata'],
#  ['control', 'control', 'wikidata'],
#  ['measure', 'quality', 'wikidata'],
#  ['physical quantity', 'individual quantity', 'wikidata'],
#  ['individual quantity', 'quantity', 'wikidata'],
#  ['physical object', 'material entity', 'wikidata'],
#  ['rule', 'artificial object', 'wikidata'],
#  ['magnitude', 'property', 'wikidata'],
#  ['social system', 'system', 'wikidata'],
#  ['physical object', 'concrete object', 'wikidata'],
#  ['intellectual property', 'erga omnes', 'wikidata'],
#  ['conceptual system', 'artificial object', 'wikidata'],
#  ['legal concept', 'term', 'wikidata'],
#  ['set', 'formalization', 'wikidata'],
#  ['unit', 'abstract entity', 'wikidata'],
#  ['observable entity', 'entity', 'wikidata'],
#  ['representation', 'relation', 'wikidata'],
#  ['class', 'data type', 'wikidata'],
#  ['specialty', 'knowledge type', 'wikidata'],
#  ['rights and privileges', 'administration', 'wikidata'],
#  ['symmetric tensor', 'tensor', 'wikidata'],
#  ['state', 'phenomenon', 'wikidata'],
#  ['unit of measurement', 'individual quantity', 'wikidata'],
#  ['linguistic form', 'linguistic unit', 'wikidata'],
#  ['administration', 'management', 'wikidata'],
#  ['right', 'law', 'wikidata'],
#  ['goods', 'product', 'wikidata'],
#  ['partial function', 'binary relation', 'wikidata'],
#  ['agent', 'subject', 'wikidata'],
#  ['word or phrase', 'linguistic form', 'wikidata'],
#  ['mathematical object', 'abstract entity', 'wikidata'],
#  ['control', 'aptitude', 'wikidata'],
#  ['state', 'property', 'wikidata'],
#  ['realizable entity', 'specifically dependent continuant', 'wikidata'],
#  ['rights', 'legal concept', 'wikidata'],
#  ['tensor', 'mathematical object', 'wikidata'],
#  ['continuant', 'entity', 'wikidata'],
#  ['concrete object', 'object', 'wikidata'],
#  ['unit', 'unit of measurement', 'wikidata'],
#  ['scalar quantity', 'scalar', 'wikidata'],
#  ['mapping', 'function', 'wikidata'],
#  ['unit', 'constituent', 'wikidata'],
#  ['set', 'multiset', 'wikidata'],
#  ['class', 'mathematical object', 'wikidata'],
#  ['sign', 'object', 'wikidata'],
#  ['intangible asset', 'intangible property', 'wikidata'],
#  ['independent continuant', 'continuant', 'wikidata'],
#  ['mental representation', 'representation', 'wikidata'],
#  ['tensor', 'multilinear map', 'wikidata'],
#  ['scalar quantity', 'physical quantity', 'wikidata'],
#  ['conceptual system', 'system', 'wikidata'],
#  ['agreement', 'consensus', 'wikidata'],
#  ['written work', 'intellectual work', 'wikidata'],
#  ['phenomenon', 'occurrent', 'wikidata'],
#  ['software', 'creative work', 'wikidata'],
#  ['product', 'artificial object', 'wikidata'],
#  ['cultural artifact', 'artificial physical object', 'wikidata'],
#  ['management', 'control', 'wikidata'],
#  ['material entity', 'independent continuant', 'wikidata'],
#  ['type', 'class', 'wikidata'],
#  ['artificial physical object', 'physical object', 'wikidata'],
#  ['intangible property', 'property', 'wikidata'],
#  ['asset', 'resource', 'wikidata'],
#  ['relation', 'property', 'wikidata'],
#  ['software', 'means', 'wikidata'],
#  ['individual quantity', 'abstract class', 'wikidata'],
#  ['mental process', 'psychological process', 'wikidata'],
#  ['emerging technology', 'technology', 'wikidata'],
#  ['mathematical model', 'model', 'wikidata'],
#  ['psychological process', 'psychological phenomenon', 'wikidata'],
#  ['conceptual model', 'knowledge organization system', 'wikidata'],
#  ['document', 'information resource', 'wikidata'],
#  ['model', 'artificial object', 'wikidata'],
#  ['applied science', 'science', 'wikidata'],
#  ['model', 'information', 'wikidata'],
#  ['learning material', 'media', 'wikidata'],
#  ['media', 'means', 'wikidata'],
#  ['thinking', 'mental process', 'wikidata'],
#  ['source of information', 'source', 'wikidata'],
#  ['hypergraph', 'diagram', 'wikidata'],
#  ['reference work', 'creative work', 'wikidata'],
#  ['biological process', 'natural process', 'wikidata'],
#  ['physical process', 'physical phenomenon', 'wikidata'],
#  ['natural process', 'process', 'wikidata'],
#  ['multigraph', 'mathematical object', 'wikidata'],
#  ['knowledge organization system', 'model', 'wikidata'],
#  ['exact science', 'science', 'wikidata'],
#  ['natural phenomenon', 'occurrence', 'wikidata'],
#  ['reasoning', 'thinking', 'wikidata'],
#  ['diagram', 'structure', 'wikidata'],
#  ['physical process', 'physicochemical process', 'wikidata'],
#  ['physical phenomenon', 'phenomenon', 'wikidata'],
#  ['biological phenomenon', 'physical phenomenon', 'wikidata'],
#  ['information resource', 'resource', 'wikidata'],
#  ['psychological phenomenon', 'occurrence', 'wikidata'],
#  ['multigraph', 'hypergraph', 'wikidata'],
#  ['reference work', 'learning material', 'wikidata'],
#  ['knowledge organization system', 'conceptual system', 'wikidata'],
#  ['data carrier', 'manifestation', 'wikidata'],
#  ['natural process', 'natural phenomenon', 'wikidata'],
#  ['manifestation', 'artificial object', 'wikidata'],
#  ['source text', 'work', 'wikidata'],
#  ['reference work', 'tertiary source', 'wikidata'],
#  ['natural phenomenon', 'phenomenon', 'wikidata'],
#  ['reference work', 'written work', 'wikidata'],
#  ['document', 'manifestation', 'wikidata'],
#  ['document', 'intellectual work', 'wikidata'],
#  ['graph', 'multigraph', 'wikidata'],
#  ['information resource', 'source of information', 'wikidata'],
#  ['artificial intelligence', 'reasoning', 'wikidata'],
#  ['psychological process', 'biological process', 'wikidata'],
#  ['source text', 'source of information', 'wikidata'],
#  ['physicochemical process', 'process', 'wikidata'],
#  ['tertiary source', 'source text', 'wikidata'],
#  ['artificial neural network', 'discriminative model', 'wikidata'],
#  ['psychological phenomenon', 'phenomenon', 'wikidata'],
#  ['reference work', 'document', 'wikidata'],
#  ['mathematical model', 'conceptual model', 'wikidata'],
#  ['technology', 'applied science', 'wikidata'],
#  ['media', 'data carrier', 'wikidata'],
#  ['biological process', 'physical process', 'wikidata'],
#  ['artificial intelligence', 'emerging technology', 'wikidata'],
#  ['mathematical model', 'intellectual work', 'wikidata'],
#  ['computer science', 'formal science', 'wikidata'],
#  ['multigraph', 'graph', 'wikidata'],
#  ['discriminative model', 'mathematical model', 'wikidata'],
#  ['scientific model', 'conceptual model', 'wikidata'],
#  ['structure', 'collective entity', 'wikidata'],
#  ['formal science', 'exact science', 'wikidata'],
#  ['mathematical model', 'scientific model', 'wikidata'],
#  ['biological process', 'biological phenomenon', 'wikidata'],
#  ['reasoning', 'abstract entity', 'wikidata'],
#  ['network', 'graph', 'wikidata'],
#  ['biological phenomenon', 'natural phenomenon', 'wikidata'],
#  ['data analysis', 'analysis', 'wikidata'],
#  ['descriptive statistic', 'statistic', 'wikidata'],
#  ['statistical method', 'method', 'wikidata'],
#  ['statistic', 'measured quantity value', 'wikidata'],
#  ['regression', 'descriptive statistic', 'wikidata'],
#  ['regression analysis', 'statistical method', 'wikidata'],
#  ['linear regression', 'regression', 'wikidata'],
#  ['statistical method', 'data analysis', 'wikidata'],
#  ['measurable function', 'function', 'wikidata'],
#  ['regression analysis', 'data analysis', 'wikidata'],
#  ['statistic', 'measurable function', 'wikidata'],
#  ['linear regression', 'regression analysis', 'wikidata'],
#  ['engineering', 'applied science', 'wikidata'],
#  ['task', 'process', 'wikidata'],
#  ['process', 'task', 'wikidata'],
#  ['encoding', 'process', 'wikidata'],
#  ['serialization', 'data processing', 'wikidata'],
#  ['serialization', 'encoding', 'wikidata'],
#  ['task', 'problem', 'wikidata'],
#  ['problem', 'situation', 'wikidata'],
#  ['condition', 'state', 'wikidata'],
#  ['task', 'task', 'wikidata'],
#  ['situation', 'condition', 'wikidata'],
#  ['data processing', 'information processing', 'wikidata'],
#  ['task', 'activity', 'wikidata'],
#  ['information processing', 'process', 'wikidata'],
#  ['process', 'process', 'wikidata'],
#  ['task', 'unit', 'wikidata'],
#  ['process', 'software', 'wikidata'],
#  ['game', 'recreative work', 'wikidata'],
#  ['recreative work', 'creative work', 'wikidata'],
#  ['audiovisual production', 'production', 'wikidata'],
#  ['economic activity', 'intentional human activity', 'wikidata'],
#  ['production', 'process', 'wikidata'],
#  ['durable good', 'goods', 'wikidata'],
#  ['production', 'economic activity', 'wikidata'],
#  ['durable good', 'product', 'wikidata'],
#  ['tangible good', 'perceptible physical object', 'wikidata'],
#  ['visual artwork', 'work of art', 'wikidata'],
#  ['cinematography', 'photography', 'wikidata'],
#  ['household goods', 'durable good', 'wikidata'],
#  ['collectible', 'product', 'wikidata'],
#  ['animation', 'filmmaking', 'wikidata'],
#  ['photography', 'industrial sector', 'wikidata'],
#  ['tangible good', 'goods', 'wikidata'],
#  ['work of art', 'collectible', 'wikidata'],
#  ['work of art', 'product', 'wikidata'],
#  ['visual artwork', 'visual work', 'wikidata'],
#  ['collectible', 'object', 'wikidata'],
#  ['perceptible physical object', 'physical object', 'wikidata'],
#  ['decorative object', 'tangible good', 'wikidata'],
#  ['filmmaking', 'cinematography', 'wikidata'],
#  ['photography', 'visual artwork', 'wikidata'],
#  ['work of art', 'creative work', 'wikidata'],
#  ['decorative object', 'household goods', 'wikidata'],
#  ['audiovisual production', 'process', 'wikidata'],
#  ['visual work', 'work', 'wikidata'],
#  ['industrial sector', 'activity', 'wikidata'],
#  ['filmmaking', 'audiovisual production', 'wikidata'],
#  ['photography', 'imaging method', 'wikidata'],
#  ['work of art', 'decorative object', 'wikidata'],
#  ['imaging method', 'technique', 'wikidata'],
#  ['computer program', 'routine', 'wikidata'],
#  ['routine', 'series', 'wikidata'],
#  ['management system', 'social system', 'wikidata'],
#  ['technical system', 'product', 'wikidata'],
#  ['technical system', 'artificial object', 'wikidata'],
#  ['information system', 'product', 'wikidata'],
#  ['technical system', 'system', 'wikidata'],
#  ['server', 'technical system', 'wikidata'],
#  ['classification', 'information handling', 'wikidata'],
#  ['information handling', 'intellectual activity', 'wikidata'],
#  ['manipulation', 'power', 'wikidata'],
#  ['information handling', 'technical activity', 'wikidata'],
#  ['technical activity', 'intentional human activity', 'wikidata'],
#  ['information handling', 'manipulation', 'wikidata'],
#  ['classification', 'process', 'wikidata'],
#  ['power', 'power', 'wikidata'],
#  ['intellectual activity', 'intentional human activity', 'wikidata'],
#  ['classification', 'assignment', 'wikidata'],
#  ['physical system', 'concrete object', 'wikidata'],
#  ['engineered physical system', 'physical system', 'wikidata'],
#  ['engineered physical system', 'technical system', 'wikidata'],
#  ['electrical network', 'network', 'wikidata'],
#  ['physical system', 'scientific object', 'wikidata'],
#  ['physical system', 'system', 'wikidata'],
#  ['electrical network', 'engineered physical system', 'wikidata'],
#  ['electronic system', 'electrical network', 'wikidata'],
#  ['computer system', 'electronic system', 'wikidata'],
#  ['trade', 'economic activity', 'wikidata'],
#  ['electronic trading', 'trade', 'wikidata'],
#  ['depicting object', 'work', 'wikidata'],
#  ['plot', 'statistical graphics', 'wikidata'],
#  ['data visualization', 'visualization', 'wikidata'],
#  ['visualization', 'technique', 'wikidata'],
#  ['human-readable medium', 'media', 'wikidata'],
#  ['visual depiction', 'type of arts', 'wikidata'],
#  ['statistical graphics', 'infographic', 'wikidata'],
#  ['infographic', 'data visualization', 'wikidata'],
#  ['type of arts', 'type', 'wikidata'],
#  ['chart', 'infographic', 'wikidata'],
#  ['chart', 'diagram', 'wikidata'],
#  ['visualization', 'human-readable medium', 'wikidata'],
#  ['depicting object', 'cultural artifact', 'wikidata'],
#  ['visualization', 'visual depiction', 'wikidata'],
#  ['visual depiction', 'depicting object', 'wikidata'],
#  ['plot', 'chart', 'wikidata'],
#  ['review', 'evaluation', 'wikidata'],
#  ['automation', 'process', 'wikidata'],
#  ['review', 'intellectual work', 'wikidata'],
#  ['test', 'intentional human activity', 'wikidata'],
#  ['information and communications technology',
#   'industrial sector',
#   'wikidata'],
#  ['IT process automation', 'business process automation', 'wikidata'],
#  ['test automation', 'IT process automation', 'wikidata'],
#  ['information and communications technology', 'technology', 'wikidata'],
#  ['process', 'activity', 'wikidata'],
#  ['automation', 'information and communications technology', 'wikidata'],
#  ['test', 'method', 'wikidata'],
#  ['automation', 'activity', 'wikidata'],
#  ['process', 'process', 'wikidata'],
#  ['product testing', 'review', 'wikidata'],
#  ['automation', 'occurrence', 'wikidata'],
#  ['penetration test', 'security testing', 'wikidata'],
#  ['algorithm', 'procedure', 'wikidata'],
#  ['control structure', 'statement', 'wikidata'],
#  ['code', 'sign', 'wikidata'],
#  ['part (piece)', 'entity', 'wikidata'],
#  ['program code', 'code', 'wikidata'],
#  ['procedure', 'intentional human activity', 'wikidata'],
#  ['language construct', 'structure', 'wikidata'],
#  ['control flow', 'program code', 'wikidata'],
#  ['component', 'part (piece)', 'wikidata'],
#  ['conditional', 'language construct', 'wikidata'],
#  ['rule-based system', 'conceptual system', 'wikidata'],
#  ['control flow', 'structure', 'wikidata'],
#  ['procedure', 'method', 'wikidata'],
#  ['statement', 'language construct', 'wikidata'],
#  ['pattern matching', 'algorithm', 'wikidata'],
#  ['language construct', 'component', 'wikidata'],
#  ['statement', 'control flow', 'wikidata'],
#  ['component', 'perceptible physical object', 'wikidata'],
#  ['conditional', 'control structure', 'wikidata'],
#  ['algorithm', 'work', 'wikidata'],
#  ['photo equipment', 'equipment', 'wikidata'],
#  ['camera', 'photo equipment', 'wikidata'],
#  ['optical instrument', 'camera and optics product', 'wikidata'],
#  ['commodity', 'goods', 'wikidata'],
#  ['equipment', 'product', 'wikidata'],
#  ['optical instrument', 'optical system', 'wikidata'],
#  ['camera', 'product', 'wikidata'],
#  ['optical instrument', 'scientific instrument', 'wikidata'],
#  ['scientific instrument', 'physical tool', 'wikidata'],
#  ['photo equipment', 'goods', 'wikidata'],
#  ['photo equipment', 'camera and optics product', 'wikidata'],
#  ['physical tool', 'artificial physical object', 'wikidata'],
#  ['physical tool', 'equipment', 'wikidata'],
#  ['camera and optics product', 'commodity', 'wikidata'],
#  ['physical tool', 'tool', 'wikidata'],
#  ['equipment', 'physical object', 'wikidata'],
#  ['camera and optics product', 'product', 'wikidata'],
#  ['tool', 'object', 'wikidata'],
#  ['commodity', 'perceptible physical object', 'wikidata'],
#  ['camera', 'optical instrument', 'wikidata'],
#  ['optical system', 'physical system', 'wikidata'],
#  ['validator', 'computer program', 'wikidata'],
#  ['functional management', 'management', 'wikidata'],
#  ['operations management', 'business administration', 'wikidata'],
#  ['business activity', 'economic activity', 'wikidata'],
#  ['administration', 'human behavior', 'wikidata'],
#  ['technology management', 'functional management', 'wikidata'],
#  ['business administration', 'business activity', 'wikidata'],
#  ['business administration', 'administration', 'wikidata'],
#  ['technology management', 'management', 'wikidata'],
#  ['administration', 'coordination', 'wikidata'],
#  ['information technology management', 'technology management', 'wikidata'],
#  ['performance management', 'operations management', 'wikidata'],
#  ['IT performance management', 'performance management', 'wikidata'],
#  ['operations management', 'functional management', 'wikidata'],
#  ['sound technology', 'engineering', 'wikidata'],
#  ['digital audio', 'sound technology', 'wikidata'],
#  ['data structure', 'data format', 'wikidata'],
#  ['immaterial component', 'component', 'wikidata'],
#  ['specification', 'document', 'wikidata'],
#  ['data', 'information', 'wikidata'],
#  ['data format', 'code', 'wikidata'],
#  ['data', 'data', 'wikidata'],
#  ['software component', 'software resource', 'wikidata'],
#  ['data format', 'specification', 'wikidata'],
#  ['data structure', 'data', 'wikidata'],
#  ['software resource', 'information resource', 'wikidata'],
#  ['data', 'source of information', 'wikidata'],
#  ['data structure', 'structure', 'wikidata'],
#  ['data', 'manifestation', 'wikidata'],
#  ['data structure', 'mathematical structure', 'wikidata'],
#  ['software component', 'immaterial component', 'wikidata'],
#  ['immaterial component', 'abstract entity', 'wikidata'],
#  ['scientific technique', 'technique', 'wikidata'],
#  ['sequencing', 'scientific technique', 'wikidata'],
#  ['electrical appliance', 'electrical load', 'wikidata'],
#  ['quantum system', 'physical system', 'wikidata'],
#  ['converter', 'entity', 'wikidata'],
#  ['physical component', 'physical object', 'wikidata'],
#  ['musical instrument', 'sound generator', 'wikidata'],
#  ['electronic musical instrument', 'electronic instrument', 'wikidata'],
#  ['quantum computer', 'quantum system', 'wikidata'],
#  ['computer', 'information processor', 'wikidata'],
#  ['music equipment', 'audio equipment', 'wikidata'],
#  ['nonbiological component', 'physical component', 'wikidata'],
#  ['musical instrument', 'music equipment', 'wikidata'],
#  ['appliance', 'physical tool', 'wikidata'],
#  ['electrical appliance', 'appliance', 'wikidata'],
#  ['electrical device', 'electrical appliance', 'wikidata'],
#  ['information processor', 'information system', 'wikidata'],
#  ['electronic musical instrument', 'musical instrument', 'wikidata'],
#  ['machine', 'converter', 'wikidata'],
#  ['electrophone', 'musical instrument', 'wikidata'],
#  ['location', 'entity', 'wikidata'],
#  ['electrical element', 'nonbiological component', 'wikidata'],
#  ['electronic instrument', 'appliance', 'wikidata'],
#  ['electrical element', 'electrical device', 'wikidata'],
#  ['audio equipment', 'appliance', 'wikidata'],
#  ['electrophone', 'electrical appliance', 'wikidata'],
#  ['electrical load', 'electrical element', 'wikidata'],
#  ['quantum computer', 'computer', 'wikidata'],
#  ['computer', 'computer file location', 'wikidata'],
#  ['computer', 'electronic musical instrument', 'wikidata'],
#  ['musical instrument', 'physical tool', 'wikidata'],
#  ['data terminal equipment', 'appliance', 'wikidata'],
#  ['computing platform', 'technical system', 'wikidata'],
#  ['machine', 'appliance', 'wikidata'],
#  ['computer', 'machine', 'wikidata'],
#  ['electronic musical instrument', 'electrophone', 'wikidata'],
#  ['computer file location', 'location', 'wikidata'],
#  ['physical component', 'part (piece)', 'wikidata'],
#  ['computing platform', 'product', 'wikidata'],
#  ['sound generator', 'appliance', 'wikidata'],
#  ['rendering', 'creation', 'wikidata'],
#  ['rendering', 'visualization', 'wikidata'],
#  ['creation', 'activity', 'wikidata'],
#  ['creation', 'planned process', 'wikidata'],
#  ['system configuration', 'group', 'wikidata'],
#  ['system configuration', 'condition', 'wikidata'],
#  ['group', 'collective entity', 'wikidata'],
#  ['system configuration', 'property', 'wikidata'],
#  ['computer configuration', 'system configuration', 'wikidata'],
#  ['combinatorial algorithm', 'algorithm', 'wikidata'],
#  ['combinatorial algorithm', 'mathematical method', 'wikidata'],
#  ['mathematical method', 'method', 'wikidata'],
#  ['sorting algorithm', 'combinatorial algorithm', 'wikidata'],
#  ['word embedding', 'embedding', 'wikidata'],
#  ['embedding', 'mapping', 'wikidata'],
#  ['embedding', 'function', 'wikidata'],
#  ['string algorithm', 'algorithm', 'wikidata'],
#  ['regular expression', 'string algorithm', 'wikidata'],
#  ['user interface', 'work', 'wikidata'],
#  ['user interface', 'interface', 'wikidata'],
#  ['interface', 'means', 'wikidata'],
#  ['computing infrastructure', 'infrastructure', 'wikidata'],
#  ['infrastructure', 'structure', 'wikidata'],
#  ['storage', 'method', 'wikidata'],
#  ['systems engineering', 'specialty', 'wikidata'],
#  ['management cybernetics', 'management', 'wikidata'],
#  ['management cybernetics', 'cybernetics', 'wikidata'],
#  ['sources of law', 'source', 'wikidata'],
#  ['backup', 'data storage on medium', 'wikidata'],
#  ['computer file management', 'command', 'wikidata'],
#  ['command', 'instruction', 'wikidata'],
#  ['cybernetics', 'systems engineering', 'wikidata'],
#  ['computer file management', 'management cybernetics', 'wikidata'],
#  ['storage', 'activity', 'wikidata'],
#  ['sources of law', 'information', 'wikidata'],
#  ['data storage on medium', 'use', 'wikidata'],
#  ['instruction', 'message', 'wikidata'],
#  ['storage', 'process', 'wikidata'],
#  ['command', 'sources of law', 'wikidata'],
#  ['data storage on medium', 'data storage', 'wikidata'],
#  ['command', 'statement', 'wikidata'],
#  ['backup', 'computer file management', 'wikidata'],
#  ['use', 'activity', 'wikidata'],
#  ['systems engineering', 'engineering', 'wikidata'],
#  ['command', 'command', 'wikidata'],
#  ['computer file management', 'control', 'wikidata'],
#  ['computer file management', 'management', 'wikidata'],
#  ['simulator', 'artefact', 'wikidata'],
#  ['artefact', 'artificial object', 'wikidata'],
#  ['neuroscience', 'science', 'wikidata'],
#  ['ratio', 'relation', 'wikidata'],
#  ['productivity', 'ratio', 'wikidata'],
#  ['operation result', 'result', 'wikidata'],
#  ['number', 'mathematical object', 'wikidata'],
#  ['ratio', 'number', 'wikidata'],
#  ['ratio', 'dimensionless quantity', 'wikidata'],
#  ['dimensionless quantity', 'individual quantity', 'wikidata'],
#  ['ratio', 'quotient', 'wikidata'],
#  ['result', 'entity', 'wikidata'],
#  ['quotient', 'operation result', 'wikidata'],
#  ['biology', 'natural science', 'wikidata'],
#  ['information science', 'science', 'wikidata'],
#  ['genetics', 'biology', 'wikidata'],
#  ['computational science', 'applied mathematics', 'wikidata'],
#  ['omics', 'specialty', 'wikidata'],
#  ['applied mathematics', 'mathematics', 'wikidata'],
#  ['computational biology', 'biology', 'wikidata'],
#  ['computational science', 'computer science', 'wikidata'],
#  ['computational biology', 'computational science', 'wikidata'],
#  ['computational biology', 'information science', 'wikidata'],
#  ['mathematics', 'natural science', 'wikidata'],
#  ['genomics', 'genetics', 'wikidata'],
#  ['natural science', 'science', 'wikidata'],
#  ['data pre-processing', 'process', 'wikidata'],
#  ['data pre-processing', 'variation', 'wikidata'],
#  ['variation', 'change', 'wikidata'],
#  ['change', 'occurrent', 'wikidata'],
#  ['data science', 'science', 'wikidata'],
#  ['academic degree', 'academic achievement', 'wikidata'],
#  ['academic degree', 'intangible asset', 'wikidata'],
#  ['human communication', 'human behavior', 'wikidata'],
#  ['social science', 'social sciences and humanities', 'wikidata'],
#  ['verbal communication', 'communication', 'wikidata'],
#  ['interaction', 'effect', 'wikidata'],
#  ['translation', 'creation', 'wikidata'],
#  ['linguistics', 'humanities', 'wikidata'],
#  ['human communication', 'intentional human activity', 'wikidata'],
#  ['human communication', 'biocommunication', 'wikidata'],
#  ['transformation', 'change', 'wikidata'],
#  ['communication', 'information exchange', 'wikidata'],
#  ['achievement', 'occurrence', 'wikidata'],
#  ['social process', 'phenomenon', 'wikidata'],
#  ['academic achievement', 'achievement', 'wikidata'],
#  ['social science', 'academic degree', 'wikidata'],
#  ['translation', 'verbal communication', 'wikidata'],
#  ['biocommunication', 'communication', 'wikidata'],
#  ['linguistics', 'social science', 'wikidata'],
#  ['computational linguistics', 'mathematical linguistics', 'wikidata'],
#  ['mathematical linguistics', 'linguistics', 'wikidata'],
#  ['effect', 'action', 'wikidata'],
#  ['translation', 'human communication', 'wikidata'],
#  ['human communication', 'communication', 'wikidata'],
#  ['information exchange', 'interaction', 'wikidata'],
#  ['qualification', 'quality', 'wikidata'],
#  ['transformation', 'process', 'wikidata'],
#  ['social process', 'process', 'wikidata'],
#  ['mathematical linguistics', 'mathematics', 'wikidata'],
#  ['communication', 'social process', 'wikidata'],
#  ['academic degree', 'qualification', 'wikidata'],
#  ['translation', 'transformation', 'wikidata'],
#  ['continuous delivery', 'DevOps', 'wikidata'],
#  ['continuous delivery', 'quality control method', 'wikidata'],
#  ['generative model', 'statistical model', 'wikidata'],
#  ['statistical model', 'mathematical model', 'wikidata'],
#  ['security', 'condition', 'wikidata'],
#  ['RNA analysis', 'biochemistry method', 'wikidata'],
#  ['lab technique', 'process', 'wikidata'],
#  ['biochemistry method', 'method', 'wikidata'],
#  ['RNA sequencing', 'RNA analysis', 'wikidata'],
#  ['lab technique', 'scientific technique', 'wikidata'],
#  ['biochemistry method', 'lab technique', 'wikidata'],
#  ['term', 'mathematical object', 'wikidata'],
#  ['parameter', 'variable', 'wikidata'],
#  ['mathematical expression', 'mathematical object', 'wikidata'],
#  ['variable', 'term', 'wikidata'],
#  ['variable', 'operand', 'wikidata'],
#  ['parameter', 'constant', 'wikidata'],
#  ['constant', 'operand', 'wikidata'],
#  ['term', 'mathematical expression', 'wikidata'],
#  ['hyperparameter', 'parameter', 'wikidata'],
#  ['parameter', 'property', 'wikidata'],
#  ['operand', 'value', 'wikidata'],
#  ['logging', 'process', 'wikidata'],
#  ['hacking tool', 'software', 'wikidata'],
#  ['data synchronization', 'synchronization', 'wikidata'],
#  ['synchronization', 'union', 'wikidata'],
#  ['union', 'entity', 'wikidata'],
#  ['data binding', 'data synchronization', 'wikidata'],
#  ['data binding', 'data mapping', 'wikidata'],
#  ['synchronization', 'activity', 'wikidata'],
#  ['data mapping', 'machine-readable data', 'wikidata'],
#  ['machine-readable data', 'data', 'wikidata'],
#  ['union', 'occurrence', 'wikidata'],
#  ['data set', 'collection', 'wikidata'],
#  ['database', 'artificial object', 'wikidata'],
#  ['knowledge graph', 'graph', 'wikidata'],
#  ['collection', 'work', 'wikidata'],
#  ['knowledge base', 'tertiary source', 'wikidata'],
#  ['knowledge base', 'database', 'wikidata'],
#  ['database', 'work', 'wikidata'],
#  ['data set', 'manifestation', 'wikidata'],
#  ['data set', 'intellectual work', 'wikidata'],
#  ['database', 'data set', 'wikidata'],
#  ['database', 'project', 'wikidata'],
#  ['project', 'planned process', 'wikidata'],
#  ['database', 'data', 'wikidata'],
#  ['documentation', 'information', 'wikidata'],
#  ['knowledge base', 'conceptual model', 'wikidata'],
#  ['knowledge graph', 'knowledge base', 'wikidata'],
#  ['collection', 'class', 'wikidata'],
#  ['knowledge base', 'documentation', 'wikidata'],
#  ['collection', 'artificial object', 'wikidata'],
#  ['astronomy', 'physical sciences', 'wikidata'],
#  ['astronomy', 'exact science', 'wikidata'],
#  ['physical sciences', 'natural science', 'wikidata'],
#  ['mathematical finance', 'finance', 'wikidata'],
#  ['finance', 'banking, finance and investment studies', 'wikidata'],
#  ['mathematical finance', 'applied mathematics', 'wikidata'],
#  ['finance', 'business management', 'wikidata'],
#  ['business management', 'management', 'wikidata'],
#  ['information services', 'service', 'wikidata'],
#  ['website', 'virtual place', 'wikidata'],
#  ['digital media', 'electronic media', 'wikidata'],
#  ['website', 'online publication', 'wikidata'],
#  ['publication', 'release', 'wikidata'],
#  ['virtual place', 'location', 'wikidata'],
#  ['digital-native publication', 'publication', 'wikidata'],
#  ['release', 'product', 'wikidata'],
#  ['e-service', 'service', 'wikidata'],
#  ['network service', 'service', 'wikidata'],
#  ['service', 'economic activity', 'wikidata'],
#  ['website', 'digital-native publication', 'wikidata'],
#  ['release', 'manifestation', 'wikidata'],
#  ['integrating resource', 'publication', 'wikidata'],
#  ['electronic media', 'media', 'wikidata'],
#  ['release', 'work', 'wikidata'],
#  ['website', 'integrating resource', 'wikidata'],
#  ['service', 'product', 'wikidata'],
#  ['service on Internet', 'media', 'wikidata'],
#  ['online publication', 'publication', 'wikidata'],
#  ['online service', 'information services', 'wikidata'],
#  ['service', 'goods and services', 'wikidata'],
#  ['annotation', 'work', 'wikidata'],
#  ['metadata', 'data', 'wikidata'],
#  ['image annotation', 'annotation', 'wikidata'],
#  ['metadata', 'secondary information', 'wikidata'],
#  ['secondary information', 'information', 'wikidata'],
#  ['annotation', 'metadata', 'wikidata'],
#  ['metadata', 'artificial object', 'wikidata'],
#  ['systems architecture', 'conceptual model', 'wikidata'],
#  ['cloud computing', 'system resource', 'wikidata'],
#  ['system resource', 'source', 'wikidata'],
#  ['software engineering', 'systems engineering', 'wikidata'],
#  ['named-entity recognition', 'problem', 'wikidata'],
#  ['physics', 'natural science', 'wikidata'],
#  ['communication system', 'technical system', 'wikidata'],
#  ['technical standard', 'document', 'wikidata'],
#  ['technical standard', 'class', 'wikidata'],
#  ['technical standard', 'reference work', 'wikidata'],
#  ['technical standard', 'service', 'wikidata'],
#  ['technical standard', 'convention', 'wikidata'],
#  ['communication protocol', 'interface standard', 'wikidata'],
#  ['File Transfer Protocol', 'communication protocol', 'wikidata'],
#  ['interface standard', 'technical standard', 'wikidata'],
#  ['communication protocol', 'technical standard', 'wikidata'],
#  ['scientific publication', 'publication', 'wikidata'],
#  ['scientific publication', 'work of science', 'wikidata'],
#  ['report', 'scientific publication', 'wikidata'],
#  ['specialized literature', 'non-fiction literature', 'wikidata'],
#  ['scientific publication', 'scientific literature', 'wikidata'],
#  ['work of science', 'nonfiction', 'wikidata'],
#  ['report', 'document', 'wikidata'],
#  ['non-fiction literature', 'written work', 'wikidata'],
#  ['business dashboard', 'report', 'wikidata'],
#  ['scientific literature', 'specialized literature', 'wikidata'],
#  ['nonfiction', 'work', 'wikidata'],
#  ['scientific publication', 'written work', 'wikidata'],
#  ['non-fiction literature', 'nonfiction', 'wikidata'],
#  ['work of science', 'written work', 'wikidata'],
#  ['scientific literature', 'nonfiction', 'wikidata'],
#  ['search', 'seeking', 'wikidata'],
#  ['image', 'record', 'wikidata'],
#  ['record', 'manifestation', 'wikidata'],
#  ['two-dimensional object', 'geometric object', 'wikidata'],
#  ['two-dimensional object', 'object', 'wikidata'],
#  ['image', 'two-dimensional object', 'wikidata'],
#  ['geometric object', 'mathematical object', 'wikidata'],
#  ['image', 'artificial object', 'wikidata'],
#  ['font', 'typeface', 'wikidata'],
#  ['typeface', 'intellectual work', 'wikidata'],
#  ['typeface', 'script style', 'wikidata'],
#  ['font', 'work', 'wikidata'],
#  ['script style', 'technique', 'wikidata'],
#  ['static website', 'website', 'wikidata'],
#  ['electronic product', 'product', 'wikidata'],
#  ['computer hardware', 'electronic machine', 'wikidata'],
#  ['physical technological component', 'physical component', 'wikidata'],
#  ['router', 'networking hardware', 'wikidata'],
#  ...]

# %%
wiki_filtered = sum([1 for x in filtered_pairs if 'wikidata' == x[2]])
print(wiki_filtered)
cso_filtered = sum([1 for x in filtered_pairs if 'cso' == x[2]])
print(cso_filtered)
# Out:
# 962
# 204

# %%
remaining_pairs
# Out:
# [['ambient intelligence', 'sensors', 'cso'],
#  ['text processing', 'computational linguistics', 'cso'],
#  ['cloud providers', 'virtual machines', 'cso'],
#  ['computational biology', 'bioinformatics', 'cso'],
#  ['real time systems', 'embedded systems', 'cso'],
#  ['electronic document identification systems', 'cryptography', 'cso'],
#  ['human computer interaction', 'computer science', 'cso'],
#  ['image super-resolution', 'low resolution images', 'cso'],
#  ['recommender systems', 'information retrieval', 'cso'],
#  ['computer networks', 'computer science', 'cso'],
#  ['digital image storage', 'image compression', 'cso'],
#  ['text classification', 'text processing', 'cso'],
#  ['synthesized speech', 'hidden markov model %28hmm%29', 'cso'],
#  ['blockchain', 'distributed ledger', 'cso'],
#  ['interpreter', 'program interpreters', 'cso'],
#  ['object detection', 'object recognition', 'cso'],
#  ['interactive computer graphics', 'computer imaging and vision', 'cso'],
#  ['digital signal processing', 'signal processing', 'cso'],
#  ['streaming videos', 'videotex', 'cso'],
#  ['videotex', 'video streaming', 'cso'],
#  ['cloud providers', 'grid computing', 'cso'],
#  ['network security', 'cryptography', 'cso'],
#  ['digital image storage', 'database systems', 'cso'],
#  ['real time systems', 'object oriented programming', 'cso'],
#  ['optical character recognition', 'character recognition', 'cso'],
#  ['cloud services', 'computing paradigm', 'cso'],
#  ['program debugging', 'computer debugging', 'cso'],
#  ['cloud computing', 'computer systems', 'cso'],
#  ['virtual machines', 'cloud computing', 'cso'],
#  ['routers', 'bandwidth', 'cso'],
#  ['user interfaces', 'human computer interaction', 'cso'],
#  ['knowledge visualization', 'information visualization', 'cso'],
#  ['face detection', 'face recognition', 'cso'],
#  ['electric network analysis', 'electric network topology', 'cso'],
#  ['language model', 'computational linguistics', 'cso'],
#  ['database schemas', 'database systems', 'cso'],
#  ['dijkstras algorithms', 'shortest path', 'cso'],
#  ['knowledge based systems', 'artificial intelligence', 'cso'],
#  ['computing environments', 'cloud computing', 'cso'],
#  ['formal logic', 'artificial intelligence', 'cso'],
#  ['image classification', 'imaging systems', 'cso'],
#  ['bioinformatics', 'computer science', 'cso'],
#  ['image retrieval', 'image segmentation', 'cso'],
#  ['telecommunication systems', 'computer systems', 'cso'],
#  ['real time systems', 'knowledge based systems', 'cso'],
#  ['distributed database systems', 'parallel processing systems', 'cso'],
#  ['information visualization', 'data visualization', 'cso'],
#  ['communication systems', 'computer systems', 'cso'],
#  ['emotion recognition', 'face recognition', 'cso'],
#  ['computer science education', 'computer programming', 'cso'],
#  ['3d pose estimation', 'gesture recognition', 'cso'],
#  ['information visualization', 'graphical user interfaces', 'cso'],
#  ['object oriented', 'object oriented programming', 'cso'],
#  ['embedded systems', 'computer systems', 'cso'],
#  ['program processors', 'parallel processing systems', 'cso'],
#  ['deep learning', 'neural networks', 'cso'],
#  ['software project', 'software design', 'cso'],
#  ['opinion mining', 'sentiment analysis', 'cso'],
#  ['ambient intelligence', 'internet of things', 'cso'],
#  ['compiler', 'program compilers', 'cso'],
#  ['information systems', 'computer systems', 'cso'],
#  ['functional languages', 'functional programming', 'cso'],
#  ['image encryptions', 'cryptography', 'cso'],
#  ['information extraction', 'information retrieval', 'cso'],
#  ['ambient intelligence', 'artificial intelligence', 'cso'],
#  ['java virtual machines', 'java', 'cso'],
#  ['dependency parsing', 'natural language processing', 'cso'],
#  ['network topology', 'computer networks', 'cso'],
#  ['image enhancement', 'image processing', 'cso'],
#  ['home automation', 'smart homes', 'cso'],
#  ['video processing', 'computer imaging and vision', 'cso'],
#  ['data compression', 'image compression', 'cso'],
#  ['digital libraries', 'database systems', 'cso'],
#  ['java', 'computer programming languages', 'cso'],
#  ['java', 'high level languages', 'cso'],
#  ['grid computing', 'parallel processing systems', 'cso'],
#  ['web development', 'web application', 'cso'],
#  ['communication networks', 'computer networks', 'cso'],
#  ['character recognition', 'pattern recognition', 'cso'],
#  ['program interpreters', 'object oriented programming', 'cso'],
#  ['robotics', 'computer science', 'cso'],
#  ['mobile applications', 'mobile telecommunication systems', 'cso'],
#  ['augmented reality', 'virtual reality', 'cso'],
#  ['text processing', 'data mining', 'cso'],
#  ['sentiment analysis', 'data mining', 'cso'],
#  ['bandwidth', 'computer networks', 'cso'],
#  ['program processors', 'microprocessor chips', 'cso'],
#  ['dependency parsing', 'computational linguistics', 'cso'],
#  ['pose estimation', 'motion estimation', 'cso'],
#  ['distributed architecture', 'network architecture', 'cso'],
#  ['game development', 'interactive computer graphics', 'cso'],
#  ['bayesian methods', 'artificial intelligence', 'cso'],
#  ['cloud services', 'software as a service', 'cso'],
#  ['architecture types', 'software architecture', 'cso'],
#  ['three dimensional computer graphics', 'computer imaging and vision', 'cso'],
#  ['natural language understanding', 'natural language processing', 'cso'],
#  ['cognitive systems', 'artificial intelligence', 'cso'],
#  ['digital image processing', 'digital image storage', 'cso'],
#  ['blockchain', 'cryptography', 'cso'],
#  ['knowledge representation', 'knowledge based systems', 'cso'],
#  ['ubiquitous computing', 'user interfaces', 'cso'],
#  ['natural language generation', 'computational linguistics', 'cso'],
#  ['continuous speech recognition', 'hidden markov models', 'cso'],
#  ['distributed ledger', 'distributed database systems', 'cso'],
#  ['3d graphics', 'three dimensional computer graphics', 'cso'],
#  ['digital watermarking', 'image processing', 'cso'],
#  ['clustering algorithms', 'data mining', 'cso'],
#  ['medical images', 'image processing', 'cso'],
#  ['smart homes', 'intelligent buildings', 'cso'],
#  ['emotion recognition', 'human computer interaction', 'cso'],
#  ['embedded processors', 'embedded software', 'cso'],
#  ['question answering', 'information retrieval', 'cso'],
#  ['computer vision', 'computer imaging and vision', 'cso'],
#  ['distributed computer systems', 'computer systems', 'cso'],
#  ['image retrieval', 'image enhancement', 'cso'],
#  ['unsupervised learning', 'clustering algorithms', 'cso'],
#  ['information retrieval', 'computer science', 'cso'],
#  ['ambient intelligence', 'ubiquitous computing', 'cso'],
#  ['virtualizations', 'cloud computing', 'cso'],
#  ['software development methods', 'software development', 'cso'],
#  ['image authentication', 'digital watermarking', 'cso'],
#  ['automata theory', 'formal languages and automata theory', 'cso'],
#  ['reactive programming', 'functional programming', 'cso'],
#  ['long short term memory neural networks', 'neural networks', 'cso'],
#  ['object recognition', 'image segmentation', 'cso'],
#  ['reinforcement learning', 'machine learning', 'cso'],
#  ['medical images', 'image analysis', 'cso'],
#  ['interactive computer graphics', 'user interfaces', 'cso'],
#  ['pose estimation', 'object recognition', 'cso'],
#  ['information security', 'network security', 'cso'],
#  ['functional languages', 'program compilers', 'cso'],
#  ['information visualization', 'interactive computer graphics', 'cso'],
#  ['semantic web', 'semantics', 'cso'],
#  ['gesture recognition', 'human computer interaction', 'cso'],
#  ['public key cryptography', 'authentication', 'cso'],
#  ['stream processing', 'database systems', 'cso'],
#  ['decision trees', 'classifiers', 'cso'],
#  ['gesture recognition', 'pattern recognition', 'cso'],
#  ['network management', 'network architecture', 'cso'],
#  ['computer debugging', 'software', 'cso'],
#  ['geo-spatial', 'geographic information system', 'cso'],
#  ['image search', 'image retrieval', 'cso'],
#  ['cloud services', 'distributed database systems', 'cso'],
#  ['program compilers', 'computer programming languages', 'cso'],
#  ['face recognition', 'pattern recognition', 'cso'],
#  ['human engineering', 'human computer interaction', 'cso'],
#  ['embedded software', 'embedded systems', 'cso'],
#  ['intelligent buildings', 'automation', 'cso'],
#  ['machine translations', 'information theory', 'cso'],
#  ['collaborative filtering', 'recommender systems', 'cso'],
#  ['knowledge representation', 'semantics', 'cso'],
#  ['natural language processing', 'artificial intelligence', 'cso'],
#  ['data mining', 'computer science', 'cso'],
#  ['high level languages', 'computer programming', 'cso'],
#  ['program interpreters', 'logic programming', 'cso'],
#  ['compiler', 'embedded systems', 'cso'],
#  ['functional programming', 'computer programming languages', 'cso'],
#  ['intelligent buildings', 'ubiquitous computing', 'cso'],
#  ['text processing', 'information retrieval', 'cso'],
#  ['information extraction', 'natural language processing', 'cso'],
#  ['network management systems', 'network management', 'cso'],
#  ['real time systems', 'digital signal processing', 'cso'],
#  ['augmented reality systems', 'augmented reality', 'cso'],
#  ['optical character recognition', 'image segmentation', 'cso'],
#  ['bayesian inference', 'bayesian methods', 'cso'],
#  ['virtual reality', 'human computer interaction', 'cso'],
#  ['dynamic analysis', 'software', 'cso'],
#  ['geographic information system', 'software', 'cso'],
#  ['low resolution images', 'high resolution image', 'cso'],
#  ['java virtual machines', 'embedded systems', 'cso'],
#  ['digital image storage', 'image segmentation', 'cso'],
#  ['design patterns', 'object oriented programming', 'cso'],
#  ['virtualization technologies', 'virtual machines', 'cso'],
#  ['virtualization technologies', 'virtualizations', 'cso'],
#  ['data analytics', 'information management', 'cso'],
#  ['stream processing', 'program processors', 'cso'],
#  ['computing paradigm', 'cloud computing', 'cso'],
#  ['online systems', 'computer systems', 'cso'],
#  ['microservices', 'software architecture patterns', 'cso'],
#  ['code generation', 'program compilers', 'cso'],
#  ['svm', 'support vector machine', 'cso'],
#  ['operating systems', 'computer science', 'cso'],
#  ['graphical user interfaces', 'user interfaces', 'cso'],
#  ['malware analysis', 'dynamic analysis', 'cso'],
#  ['network security', 'computer networks', 'cso'],
#  ['bayesian inference', 'inference engines', 'cso'],
#  ['motion planning', 'mobile robots', 'cso'],
#  ['internet of things', 'architecture types', 'cso'],
#  ['image enhancement', 'image analysis', 'cso'],
#  ['computing resource', 'cloud computing', 'cso'],
#  ['video streaming', 'multimedia systems', 'cso'],
#  ['distributed systems', 'distributed computer systems', 'cso'],
#  ['image retrieval', 'database systems', 'cso'],
#  ['sentiment analysis', 'computational linguistics', 'cso'],
#  ['cloud services', 'computing environments', 'cso'],
#  ['computer systems', 'computer science', 'cso'],
#  ['machine learning', 'artificial intelligence', 'cso'],
#  ['recurrent neural networks', 'neural networks', 'cso'],
#  ['real time systems', 'mobile robots', 'cso'],
#  ['smart contracts', 'distributed ledger', 'cso'],
#  ['support vector machine', 'classifiers', 'cso'],
#  ['image analysis', 'computer imaging and vision', 'cso'],
#  ['gesture recognition', 'computer vision', 'cso'],
#  ['kalman filters', 'signal processing', 'cso'],
#  ['ann', 'backpropagation algorithm', 'cso'],
#  ['medical image processing', 'medical images', 'cso'],
#  ['natural language generation', 'natural language processing', 'cso'],
#  ['continuous speech recognition', 'hidden markov model %28hmm%29', 'cso'],
#  ['hidden markov models', 'markov processes', 'cso'],
#  ['logic programming', 'computer programming languages', 'cso'],
#  ['anomaly detection', 'intrusion detection', 'cso'],
#  ['microservices', 'architecture types', 'cso'],
#  ['file systems', 'operating systems', 'cso'],
#  ['program compilers', 'parallel processing systems', 'cso'],
#  ['artificial intelligence', 'computer science', 'cso'],
#  ['3d pose estimation', 'pose estimation', 'cso'],
#  ['computational linguistics', 'database systems', 'cso'],
#  ['signal to noise ratio', 'signal processing', 'cso'],
#  ['high resolution image', 'imaging systems', 'cso'],
#  ['program debugging', 'software quality', 'cso'],
#  ['electronic document identification systems', 'authentication', 'cso'],
#  ['image segmentation', 'image processing', 'cso'],
#  ['synthesized speech', 'hidden markov models', 'cso'],
#  ['image authentication', 'authentication', 'cso'],
#  ['cloud services', 'cloud providers', 'cso'],
#  ['genetic algorithms', 'artificial intelligence', 'cso'],
#  ['relation extraction', 'information extraction', 'cso'],
#  ['digital libraries', 'user interfaces', 'cso'],
#  ['decision trees', 'data mining', 'cso'],
#  ['mobile robots', 'robotics', 'cso'],
#  ['feedforward neural networks', 'neural networks', 'cso'],
#  ['online social networks', 'online systems', 'cso'],
#  ['image segmentation', 'image analysis', 'cso'],
#  ['logic programming', 'formal logic', 'cso'],
#  ['question answering', 'natural language processing', 'cso'],
#  ['inference engines', 'artificial intelligence', 'cso'],
#  ['program interpreters', 'program compilers', 'cso'],
#  ['sentiment analysis', 'natural language processing', 'cso'],
#  ['image processing', 'computer imaging and vision', 'cso'],
#  ['embedded processors', 'program processors', 'cso'],
#  ['digital image storage', 'imaging systems', 'cso'],
#  ['numerical optimizations', 'optimization problems', 'cso'],
#  ['theoretical computer science', 'computer science', 'cso'],
#  ['text mining', 'text processing', 'cso'],
#  ['computer programming languages', 'computer programming', 'cso'],
#  ['public key cryptography', 'network security', 'cso'],
#  ['object oriented programming', 'computer programming', 'cso'],
#  ['software as a service', 'cloud computing', 'cso'],
#  ['dimensionality reduction', 'pattern recognition', 'cso'],
#  ['game development', 'software design', 'cso'],
#  ['naive bayes classifiers', 'classifiers', 'cso'],
#  ['pattern recognition', 'machine learning', 'cso'],
#  ['superresolution', 'optical resolving power', 'cso'],
#  ['software quality', 'software design', 'cso'],
#  ['software', 'computer science', 'cso'],
#  ['formal languages and automata theory',
#   'theoretical computer science',
#   'cso'],
#  ['high resolution image', 'superresolution', 'cso'],
#  ['design patterns', 'software architecture', 'cso'],
#  ['java virtual machines', 'virtual machines', 'cso'],
#  ['web crawlers', 'web content', 'cso'],
#  ['geographical information system', 'geographic information system', 'cso'],
#  ['translation %28languages%29', 'computational linguistics', 'cso'],
#  ['backpropagation algorithm', 'neural networks', 'cso'],
#  ['software design', 'software engineering', 'cso'],
#  ['system level simulation', 'cellular network', 'cso'],
#  ['translation %28languages%29', 'automata theory', 'cso'],
#  ['question answering', 'computational linguistics', 'cso'],
#  ['object recognition', 'pattern recognition', 'cso'],
#  ['machine translations', 'translation %28languages%29', 'cso'],
#  ['image retrieval', 'pattern recognition', 'cso'],
#  ['web crawlers', 'search engines', 'cso'],
#  ['information management', 'database systems', 'cso'],
#  ['mobile application development', 'mobile applications', 'cso'],
#  ['unscented kalman filter', 'kalman filters', 'cso'],
#  ['continuous speech recognition', 'computational linguistics', 'cso'],
#  ['distributed database systems', 'query languages', 'cso'],
#  ['malware analysis', 'malware detection', 'cso'],
#  ['bibliographic retrieval systems', 'digital libraries', 'cso'],
#  ['computer security', 'computer science', 'cso'],
#  ['numerical optimizations', 'evolutionary algorithms', 'cso'],
#  ['evolutionary algorithms', 'genetic algorithms', 'cso'],
#  ['query languages', 'database systems', 'cso'],
#  ['natural language understanding', 'knowledge representation', 'cso'],
#  ['text processing', 'natural language processing', 'cso'],
#  ['computer programming', 'computer science', 'cso'],
#  ['real time systems', 'online systems', 'cso'],
#  ['software architecture', 'software design', 'cso'],
#  ['java virtual machines', 'program compilers', 'cso'],
#  ['dimensionality reduction', 'discriminant analysis', 'cso'],
#  ['computer imaging and vision', 'computer science', 'cso'],
#  ['program debugging', 'computer programming', 'cso'],
#  ['image search', 'search engines', 'cso'],
#  ['medical images', 'bioinformatics', 'cso'],
#  ['hidden markov model %28hmm%29', 'markov processes', 'cso'],
#  ['system level simulation', 'mobile telecommunication systems', 'cso'],
#  ['network architecture', 'computer networks', 'cso'],
#  ['java', 'object oriented programming', 'cso'],
#  ['cloud providers', 'virtualizations', 'cso'],
#  ['database systems', 'computer systems', 'cso'],
#  ['image retrieval', 'information retrieval', 'cso'],
#  ['neural networks', 'machine learning', 'cso'],
#  ['data analytics', 'data mining', 'cso'],
#  ['software development', 'software project', 'cso'],
#  ['electric network topology', 'network topology', 'cso'],
#  ['classifiers', 'machine learning', 'cso'],
#  ['machine translations', 'natural language processing', 'cso'],
#  ['software architecture patterns', 'software architecture', 'cso'],
#  ['parallel processing systems', 'distributed systems', 'cso'],
#  ['web servers', 'servers', 'cso'],
#  ['distributed architecture', 'distributed systems', 'cso'],
#  ['cloud services', 'computing resource', 'cso'],
#  ['information extraction', 'data mining', 'cso'],
#  ['software development', 'software architecture', 'cso'],
#  ['face recognition', 'image processing', 'cso'],
#  ['software engineering', 'computer science', 'cso'],
#  ['ambient intelligence', 'telecommunication systems', 'cso'],
#  ['computing paradigm', 'grid computing', 'cso'],
#  ['risk management tool', 'management tool', 'wikidata'],
#  ['class', 'abstract entity', 'wikidata'],
#  ['console application', 'application', 'wikidata'],
#  ['constituent', 'emic unit', 'wikidata'],
#  ['application', 'software', 'wikidata'],
#  ['class', 'abstract entity', 'wikidata'],
#  ['system', 'abstract entity', 'wikidata'],
#  ['network', 'system', 'wikidata'],
#  ['machine learning', 'computer science', 'wikidata'],
#  ['knowledge organization system', 'rule', 'wikidata'],
#  ['variational auto-encoder', 'autoencoder', 'wikidata'],
#  ['artificial neural network', 'machine learning', 'wikidata'],
#  ['knowledge organization system', 'reference work', 'wikidata'],
#  ['artificial neural network', 'neural network', 'wikidata'],
#  ['artificial neural network', 'artificial intelligence', 'wikidata'],
#  ['neural network', 'network', 'wikidata'],
#  ['autoencoder', 'artificial neural network', 'wikidata'],
#  ['machine learning', 'artificial intelligence', 'wikidata'],
#  ['artificial intelligence', 'computer science', 'wikidata'],
#  ['graph neural network', 'neural network', 'wikidata'],
#  ['measured quantity value', 'value', 'wikidata'],
#  ['computer program', 'program', 'wikidata'],
#  ['utility software', 'system software', 'wikidata'],
#  ['program', 'software', 'wikidata'],
#  ['password manager', 'utility software', 'wikidata'],
#  ['system software', 'software', 'wikidata'],
#  ['utility software', 'computer program', 'wikidata'],
#  ['content management system', 'computer program', 'wikidata'],
#  ['content management system', 'software', 'wikidata'],
#  ['content management system', 'management system', 'wikidata'],
#  ['editor', 'application', 'wikidata'],
#  ['text editor', 'editor', 'wikidata'],
#  ['editor', 'interactive computing', 'wikidata'],
#  ['interactive computing', 'software', 'wikidata'],
#  ['text editor', 'application', 'wikidata'],
#  ['game server', 'server software', 'wikidata'],
#  ['server software', 'software', 'wikidata'],
#  ['server', 'data processing system', 'wikidata'],
#  ['data processing system', 'information system', 'wikidata'],
#  ['information system', 'software', 'wikidata'],
#  ['server software', 'server', 'wikidata'],
#  ['information system', 'system', 'wikidata'],
#  ['integrated development environment', 'deployment environment', 'wikidata'],
#  ['integrated development environment', 'programming tool', 'wikidata'],
#  ['integrated development environment', 'application', 'wikidata'],
#  ['source code editor', 'text editor', 'wikidata'],
#  ['integrated development environment', 'source code editor', 'wikidata'],
#  ['deployment environment', 'computer system', 'wikidata'],
#  ['programming tool', 'utility software', 'wikidata'],
#  ['source code editor', 'programming tool', 'wikidata'],
#  ['algorithmic trading', 'electronic trading', 'wikidata'],
#  ['middleware', 'system software', 'wikidata'],
#  ['software testing', 'product testing', 'wikidata'],
#  ['software testing', 'test', 'wikidata'],
#  ['business process automation', 'process automation', 'wikidata'],
#  ['test automation', 'automation', 'wikidata'],
#  ['test automation', 'software', 'wikidata'],
#  ['product testing', 'test', 'wikidata'],
#  ['test automation', 'software testing', 'wikidata'],
#  ['process automation', 'automation', 'wikidata'],
#  ['non-functional testing', 'software testing', 'wikidata'],
#  ['security testing', 'non-functional testing', 'wikidata'],
#  ['non-functional testing', 'product testing', 'wikidata'],
#  ['conditional', 'statement', 'wikidata'],
#  ['code', 'rule-based system', 'wikidata'],
#  ['knowledge-based system', 'information system', 'wikidata'],
#  ['rule-based system', 'knowledge-based system', 'wikidata'],
#  ['pattern matching', 'conditional', 'wikidata'],
#  ['IT performance management',
#   'information technology management',
#   'wikidata'],
#  ['application performance management',
#   'IT performance management',
#   'wikidata'],
#  ['feature learning', 'machine learning', 'wikidata'],
#  ['data structure', 'software component', 'wikidata'],
#  ['computer', 'data terminal equipment', 'wikidata'],
#  ['computer', 'computing platform', 'wikidata'],
#  ['computer', 'IT system', 'wikidata'],
#  ['IT system', 'information system', 'wikidata'],
#  ['HTTP server', 'web server', 'wikidata'],
#  ['web server', 'server software', 'wikidata'],
#  ['regular expression', 'pattern matching', 'wikidata'],
#  ['text-based user interface', 'software', 'wikidata'],
#  ['text-based user interface', 'user interface', 'wikidata'],
#  ['command-line interface', 'text-based user interface', 'wikidata'],
#  ['Internet bot', 'computer program', 'wikidata'],
#  ['debugger', 'programming tool', 'wikidata'],
#  ['software library', 'programming tool', 'wikidata'],
#  ['software engine', 'software framework', 'wikidata'],
#  ['software library', 'software component', 'wikidata'],
#  ['game engine', 'utility software', 'wikidata'],
#  ['software framework', 'computer program', 'wikidata'],
#  ['software framework', 'computing infrastructure', 'wikidata'],
#  ['game engine', 'software engine', 'wikidata'],
#  ['software framework', 'software library', 'wikidata'],
#  ['game engine', 'middleware', 'wikidata'],
#  ['software framework', 'computing platform', 'wikidata'],
#  ['data storage', 'information processing', 'wikidata'],
#  ['data storage', 'storage', 'wikidata'],
#  ['multiplayer game', 'game', 'wikidata'],
#  ['genomics', 'omics', 'wikidata'],
#  ['genomics', 'computational biology', 'wikidata'],
#  ['feature engineering', 'data pre-processing', 'wikidata'],
#  ['machine translation', 'computational linguistics', 'wikidata'],
#  ['machine translation', 'translation', 'wikidata'],
#  ['neural machine translation', 'statistical machine translation', 'wikidata'],
#  ['statistical machine translation', 'machine translation', 'wikidata'],
#  ['machine translation software', 'computer program', 'wikidata'],
#  ['computational linguistics', 'computer science', 'wikidata'],
#  ['neural machine translation', 'machine translation software', 'wikidata'],
#  ['DevOps', 'software development methodology', 'wikidata'],
#  ['software development methodology', 'methodology', 'wikidata'],
#  ['artificial intelligence model', 'software', 'wikidata'],
#  ['generative adversarial network', 'generative model', 'wikidata'],
#  ['generative adversarial network',
#   'generative artificial intelligence',
#   'wikidata'],
#  ['generative artificial intelligence',
#   'artificial intelligence model',
#   'wikidata'],
#  ['generative artificial intelligence', 'artificial intelligence', 'wikidata'],
#  ['artificial intelligence model', 'artificial neural network', 'wikidata'],
#  ['generative adversarial network', 'artificial neural network', 'wikidata'],
#  ['security', 'action', 'wikidata'],
#  ['static program analysis tool', 'application', 'wikidata'],
#  ['static program analysis tool', 'programming tool', 'wikidata'],
#  ['logging', 'software', 'wikidata'],
#  ['HTTP client', 'client', 'wikidata'],
#  ['client', 'software', 'wikidata'],
#  ['data synchronization', 'data management', 'wikidata'],
#  ['documentation', 'depicting object', 'wikidata'],
#  ['banking, finance and investment studies',
#   'commerce, management, tourism and services',
#   'wikidata'],
#  ['online service', 'service on Internet', 'wikidata'],
#  ['service on Internet', 'network service', 'wikidata'],
#  ['network service', 'middleware of distributed system', 'wikidata'],
#  ['service on Internet', 'e-service', 'wikidata'],
#  ['middleware of distributed system', 'middleware', 'wikidata'],
#  ['website', 'software', 'wikidata'],
#  ['website', 'digital media', 'wikidata'],
#  ['website', 'online service', 'wikidata'],
#  ['graphics engine', 'software engine', 'wikidata'],
#  ['web browser engine', 'rendering software', 'wikidata'],
#  ['web browser engine', 'software engine', 'wikidata'],
#  ['graphics software', 'editor', 'wikidata'],
#  ['graphics software', 'computer program', 'wikidata'],
#  ['graphics software', 'application', 'wikidata'],
#  ['rendering software', 'graphics software', 'wikidata'],
#  ['automatic image annotation', 'image annotation', 'wikidata'],
#  ['image captioning', 'automatic image annotation', 'wikidata'],
#  ['software engineering', 'computer science', 'wikidata'],
#  ['cloud computing', 'computing platform', 'wikidata'],
#  ['cloud computing', 'service on Internet', 'wikidata'],
#  ['software architecture', 'systems architecture', 'wikidata'],
#  ['serverless computing', 'applications architecture', 'wikidata'],
#  ['serverless computing', 'cloud computing', 'wikidata'],
#  ['software architecture', 'software engineering', 'wikidata'],
#  ['enterprise architecture', 'software architecture', 'wikidata'],
#  ['applications architecture',
#   'information technology architecture',
#   'wikidata'],
#  ['information technology architecture',
#   'enterprise architecture',
#   'wikidata'],
#  ['serverless computing', 'execution model', 'wikidata'],
#  ['interface standard', 'communication system', 'wikidata'],
#  ['convention', 'class', 'wikidata'],
#  ['automated machine learning', 'machine learning', 'wikidata'],
#  ['Web content management system', 'content management system', 'wikidata'],
#  ['activity recognition', 'computer science', 'wikidata'],
#  ['IRC bot', 'Internet bot', 'wikidata'],
#  ['deep neural network', 'artificial neural network', 'wikidata'],
#  ['information security', 'security', 'wikidata'],
#  ['digital security', 'information security', 'wikidata'],
#  ['concurrent computing', 'computer programming', 'wikidata'],
#  ['parallel computing', 'concurrent computing', 'wikidata'],
#  ['distributed computing', 'parallel computing', 'wikidata'],
#  ['edge computing', 'distributed computing', 'wikidata'],
#  ['distributed computing', 'computer science', 'wikidata'],
#  ['deep learning', 'machine learning method', 'wikidata'],
#  ['deep reinforcement learning', 'deep learning', 'wikidata'],
#  ['reinforcement learning', 'machine learning', 'wikidata'],
#  ['deep reinforcement learning', 'reinforcement learning', 'wikidata'],
#  ['instant messaging', 'remote communication', 'wikidata'],
#  ['instant messaging', 'software', 'wikidata'],
#  ['software system', 'software', 'wikidata'],
#  ['graph database', 'database management system', 'wikidata'],
#  ['database management system', 'software system', 'wikidata'],
#  ['graph database', 'database', 'wikidata'],
#  ['transfer learning', 'machine learning', 'wikidata'],
#  ['web browser', 'HTTP client', 'wikidata'],
#  ['web browser', 'application', 'wikidata'],
#  ['web browser', 'computing platform', 'wikidata'],
#  ['browser', 'utility software', 'wikidata'],
#  ['web browser', 'browser', 'wikidata'],
#  ['softphone', 'application', 'wikidata'],
#  ['distributed multimedia communications platform',
#   'instant messaging',
#   'wikidata'],
#  ['distributed multimedia communications platform',
#   'computing platform',
#   'wikidata'],
#  ['distributed multimedia communications platform', 'softphone', 'wikidata'],
#  ['data storage medium', 'storage', 'wikidata'],
#  ['content analysis', 'documentary analysis', 'wikidata'],
#  ['text analysis', 'content analysis', 'wikidata'],
#  ['documentary analysis', 'qualitative research', 'wikidata'],
#  ['qualitative research', 'research', 'wikidata'],
#  ['misuse detection', 'security management', 'wikidata'],
#  ['system administration', 'systems management', 'wikidata'],
#  ['database administration', 'data management', 'wikidata'],
#  ['systems management', 'information technology management', 'wikidata'],
#  ['database administration', 'system administration', 'wikidata'],
#  ['multimedia software', 'application', 'wikidata'],
#  ['media player software', 'multimedia software', 'wikidata'],
#  ['audio player software', 'media player software', 'wikidata'],
#  ['electronic trading platform', 'application', 'wikidata'],
#  ['publishing software', 'software', 'wikidata'],
#  ['static site generator', 'web template system', 'wikidata'],
#  ['desktop publishing software', 'publishing software', 'wikidata'],
#  ['web template system', 'desktop publishing software', 'wikidata'],
#  ['static site generator', 'web framework', 'wikidata'],
#  ['desktop publishing software', 'graphics software', 'wikidata'],
#  ['web framework', 'software framework', 'wikidata'],
#  ['desktop publishing software', 'editor', 'wikidata'],
#  ['video game', 'electronic game', 'wikidata'],
#  ['video game', 'application', 'wikidata'],
#  ['electronic game', 'game', 'wikidata'],
#  ['video game', 'entertainment software', 'wikidata'],
#  ['entertainment software', 'software', 'wikidata'],
#  ['video game', 'video games, consoles and accessories', 'wikidata'],
#  ['chatbot', 'software agent', 'wikidata'],
#  ['artificially intelligent entity', 'agent', 'wikidata'],
#  ['software agent', 'computer program', 'wikidata'],
#  ['software agent', 'artificially intelligent entity', 'wikidata'],
#  ['package management system', 'management system', 'wikidata'],
#  ['digital distribution platform', 'file hosting service', 'wikidata'],
#  ['online database', 'online service', 'wikidata'],
#  ['digital distribution platform', 'online database', 'wikidata'],
#  ['online database', 'database', 'wikidata'],
#  ['online database', 'website', 'wikidata'],
#  ['package management system', 'digital distribution platform', 'wikidata'],
#  ['package management system', 'software', 'wikidata'],
#  ['unit testing', 'software testing', 'wikidata'],
#  ['Topic modeling', 'text mining', 'wikidata'],
#  ['continuous integration', 'computing platform', 'wikidata'],
#  ['kernel', 'operating system component', 'wikidata'],
#  ['operating system component', 'software component', 'wikidata']]

# %%
hex_colors = ['#FF0000', '#00FF00', '#0000FF', '#FFFF00', '#00FFFF', '#FF00FF', '#800000', '#008000', '#000080']

origin_to_color = {'cso': hex_colors[0], 'wikidata': hex_colors[1], 'gitranking': hex_colors[2], 
                   'root': hex_colors[3]}
nodes = [(x, y, origin_to_color[t]) for x, y, t in combined_taxonomy.pairs if [x, y, t] not in filtered_pairs]
df = pd.DataFrame(nodes, columns=['source', 'target', 'color'])
df.to_csv('../data/interim/joined_graph_combined_filtered_new.csv', index=False)

# %%
a = []
for i in combined_taxonomy.pairs:
    if i in filtered_pairs:
        a.append(i)
print(len(a))
print(len(combined_taxonomy.pairs))
print(len(nodes))
# Out:
# 1166
# 1715
# 549

# %%
for node in no_parent:
    g.add_edges_from([(node, 'root', {"origin": 'root'})])

# %%
nx.shortest_path_length(g, 'root')
# Out:
# {'root': 0}

# %%
G = g
paths = []
sink_nodes = [node for node, outdegree in G.out_degree(G.nodes()) if outdegree == 0]
source_nodes = [node for node, indegree in G.in_degree(G.nodes()) if indegree == 0]
for source, sink in [(source, sink) for sink in sink_nodes for source in source_nodes]:
    for path in nx.all_simple_paths(G, source=source, target=sink):
        paths.append(path)

# %%
from collections import defaultdict

paths_passing_throught_node = defaultdict(list)
for node in G.nodes():
    paths_passing_throught_node[node].extend([path for path in paths if node in path])

# %%
distances = [len(x) for x in paths]

# %%
distances
# Out:
# [4,
#  4,
#  5,
#  4,
#  7,
#  6,
#  5,
#  7,
#  6,
#  6,
#  5,
#  6,
#  6,
#  5,
#  8,
#  6,
#  5,
#  3,
#  7,
#  6,
#  3,
#  6,
#  5,
#  4,
#  5,
#  4,
#  4,
#  5,
#  4,
#  7,
#  5,
#  6,
#  5,
#  5,
#  4,
#  7,
#  5,
#  6,
#  6,
#  5,
#  3,
#  4,
#  6,
#  5,
#  3,
#  7,
#  5,
#  3,
#  5,
#  6,
#  7,
#  12,
#  7,
#  4,
#  4,
#  4,
#  4,
#  6,
#  5,
#  4,
#  7,
#  6,
#  4,
#  3,
#  5,
#  4,
#  7,
#  5,
#  4,
#  6,
#  5,
#  5,
#  4,
#  7,
#  5,
#  3,
#  6,
#  6,
#  5,
#  6,
#  7,
#  6,
#  7,
#  6,
#  4,
#  3,
#  4,
#  5,
#  4,
#  3,
#  3,
#  6,
#  5,
#  3,
#  3,
#  7,
#  6,
#  5,
#  6,
#  5,
#  6,
#  6,
#  11,
#  5,
#  6,
#  6,
#  6,
#  5,
#  8,
#  6,
#  6,
#  6,
#  5,
#  4,
#  5,
#  4,
#  6,
#  5,
#  4,
#  7,
#  6,
#  4,
#  3,
#  6,
#  5,
#  6,
#  5,
#  6,
#  5,
#  6,
#  5,
#  8,
#  6,
#  3,
#  7,
#  5,
#  5,
#  5,
#  5,
#  6,
#  6,
#  5,
#  3,
#  3,
#  5,
#  4,
#  7,
#  5,
#  4,
#  5,
#  4,
#  7,
#  8,
#  8,
#  6,
#  5,
#  3,
#  5,
#  4,
#  3,
#  5,
#  5,
#  7,
#  6,
#  3,
#  5,
#  7,
#  4,
#  3,
#  7,
#  7,
#  6,
#  6,
#  5,
#  3,
#  6,
#  7,
#  5,
#  7,
#  8,
#  3,
#  3,
#  8,
#  9,
#  8,
#  8,
#  7,
#  4,
#  7,
#  8,
#  5,
#  3,
#  4,
#  3,
#  4,
#  5,
#  4,
#  5,
#  6,
#  5,
#  6,
#  7,
#  5,
#  3,
#  4,
#  4,
#  5,
#  4,
#  7,
#  6,
#  7,
#  7,
#  6,
#  6,
#  3,
#  6,
#  8,
#  9,
#  6,
#  7,
#  6,
#  5,
#  3,
#  3,
#  6,
#  4,
#  5,
#  4,
#  5,
#  5,
#  4,
#  7,
#  5,
#  4,
#  6,
#  4,
#  3,
#  5,
#  5,
#  6,
#  7,
#  4,
#  4,
#  7,
#  8,
#  6,
#  7,
#  5,
#  10,
#  11,
#  6,
#  8,
#  5,
#  6,
#  3,
#  3,
#  4,
#  3,
#  3,
#  4,
#  7,
#  8,
#  8,
#  6,
#  3,
#  4,
#  6,
#  7,
#  7,
#  5,
#  3,
#  3,
#  3,
#  3,
#  7,
#  5,
#  8,
#  6,
#  3,
#  8,
#  8,
#  7,
#  7,
#  6,
#  5,
#  3,
#  6,
#  6,
#  5,
#  5,
#  6,
#  5,
#  3,
#  5,
#  7,
#  8,
#  4,
#  3,
#  6,
#  6,
#  5,
#  5,
#  3,
#  5,
#  10,
#  11,
#  6,
#  8,
#  5,
#  5,
#  10,
#  11,
#  6,
#  8,
#  5,
#  8,
#  7,
#  8,
#  8,
#  4,
#  3,
#  9,
#  8,
#  7,
#  5,
#  5,
#  10,
#  4,
#  3,
#  5,
#  4,
#  5,
#  6,
#  6,
#  5,
#  5,
#  7,
#  5,
#  4,
#  7,
#  3,
#  8,
#  9,
#  7,
#  6,
#  6,
#  5,
#  5,
#  4,
#  7,
#  4,
#  4,
#  7,
#  6,
#  4,
#  6,
#  5,
#  5,
#  6,
#  6,
#  3,
#  5,
#  4,
#  5,
#  3,
#  6,
#  7,
#  8,
#  3,
#  5,
#  4,
#  6,
#  7,
#  7,
#  6,
#  6,
#  3,
#  3,
#  3,
#  5,
#  7,
#  5,
#  5,
#  10,
#  11,
#  6,
#  8,
#  5,
#  8,
#  8,
#  7,
#  9,
#  8,
#  9,
#  9,
#  5,
#  3,
#  5,
#  4,
#  5,
#  4,
#  3,
#  7,
#  5,
#  3,
#  6,
#  7,
#  8,
#  13,
#  7,
#  12,
#  5,
#  4,
#  4,
#  5,
#  4,
#  5,
#  3,
#  5,
#  3,
#  7,
#  6,
#  9,
#  7,
#  3,
#  4,
#  3]

# %%
import numpy as np

print(np.max(distances))
print(np.min(distances))
print(np.mean(distances))
print(np.std(distances))
print(np.median(distances))
# Out:
# 13
# 3
# 5.526932084309133
# 1.8045222148698772
# 5.0

# %%
paths
# Out:
# [['network security', 'computer networks', 'computer science', 'root'],
#  ['network security', 'computer security', 'computer science', 'root'],
#  ['network security',
#   'computer security',
#   'information security',
#   'security',
#   'root'],
#  ['network security', 'computer security', 'security', 'root'],
#  ['iot',
#   'architecture types',
#   'software architecture',
#   'software design',
#   'software engineering',
#   'computer science',
#   'root'],
#  ['iot',
#   'architecture types',
#   'software architecture',
#   'software engineering',
#   'computer science',
#   'root'],
#  ['iot',
#   'architecture types',
#   'software architecture',
#   'systems architecture',
#   'root'],
#  ['optical character recognition',
#   'character recognition',
#   'pattern recognition',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['optical character recognition',
#   'character recognition',
#   'pattern recognition',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['optical character recognition',
#   'pattern recognition',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['optical character recognition',
#   'pattern recognition',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['parallel processing systems',
#   'distributed systems',
#   'distributed computer systems',
#   'computer systems',
#   'computer science',
#   'root'],
#  ['relation extraction',
#   'information extraction',
#   'natural language processing',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['relation extraction',
#   'information extraction',
#   'natural language processing',
#   'computer science',
#   'root'],
#  ['relation extraction',
#   'information extraction',
#   'natural language processing',
#   'computational linguistics',
#   'database systems',
#   'computer systems',
#   'computer science',
#   'root'],
#  ['relation extraction',
#   'information extraction',
#   'natural language processing',
#   'computational linguistics',
#   'computer science',
#   'root'],
#  ['relation extraction',
#   'information extraction',
#   'information retrieval',
#   'computer science',
#   'root'],
#  ['theoretical computer science', 'computer science', 'root'],
#  ['emotion recognition',
#   'face recognition',
#   'pattern recognition',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['emotion recognition',
#   'face recognition',
#   'pattern recognition',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['emotion recognition', 'recognition', 'root'],
#  ['data clustering',
#   'cluster analysis',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['data clustering',
#   'cluster analysis',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['data clustering', 'cluster analysis', 'data analysis', 'root'],
#  ['data clustering',
#   'cluster analysis',
#   'data mining',
#   'computer science',
#   'root'],
#  ['three dimensional computer graphics',
#   'computer imaging and vision',
#   'computer science',
#   'root'],
#  ['unscented kalman filter', 'kalman filters', 'signal processing', 'root'],
#  ['question answering',
#   'natural language processing',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['question answering',
#   'natural language processing',
#   'computer science',
#   'root'],
#  ['question answering',
#   'natural language processing',
#   'computational linguistics',
#   'database systems',
#   'computer systems',
#   'computer science',
#   'root'],
#  ['question answering',
#   'natural language processing',
#   'computational linguistics',
#   'computer science',
#   'root'],
#  ['question answering',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['question answering',
#   'natural-language user interface',
#   'voice user interface',
#   'user interface',
#   'root'],
#  ['natural language generation',
#   'natural language processing',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['natural language generation',
#   'natural language processing',
#   'computer science',
#   'root'],
#  ['natural language generation',
#   'natural language processing',
#   'computational linguistics',
#   'database systems',
#   'computer systems',
#   'computer science',
#   'root'],
#  ['natural language generation',
#   'natural language processing',
#   'computational linguistics',
#   'computer science',
#   'root'],
#  ['program debugging',
#   'software quality',
#   'software design',
#   'software engineering',
#   'computer science',
#   'root'],
#  ['support vector machine',
#   'classifiers',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['support vector machine',
#   'classifiers',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['support vector machine', 'classification algorithm', 'root'],
#  ['support vector machine',
#   'supervised learning',
#   'machine learning method',
#   'root'],
#  ['support vector machine',
#   'supervised learning',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['support vector machine',
#   'supervised learning',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['mobile application development', 'mobile applications', 'root'],
#  ['mobile application development',
#   'software development',
#   'software project',
#   'software design',
#   'software engineering',
#   'computer science',
#   'root'],
#  ['image segmentation',
#   'image analysis',
#   'computer imaging and vision',
#   'computer science',
#   'root'],
#  ['image segmentation', 'computer vision', 'root'],
#  ['web development', 'web application', 'website', 'digital media', 'root'],
#  ['web development',
#   'web application',
#   'website',
#   'software',
#   'computer science',
#   'root'],
#  ['web development',
#   'web application',
#   'website',
#   'online service',
#   'service on Internet',
#   'e-service',
#   'root'],
#  ['web development',
#   'web application',
#   'website',
#   'online service',
#   'service on Internet',
#   'network service',
#   'middleware of distributed system',
#   'middleware',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['web development',
#   'web application',
#   'Internet application',
#   'application',
#   'software',
#   'computer science',
#   'root'],
#  ['telecommunication systems', 'computer systems', 'computer science', 'root'],
#  ['data analytics', 'data mining', 'computer science', 'root'],
#  ['streaming video', 'videotex', 'video streaming', 'root'],
#  ['decision trees', 'data mining', 'computer science', 'root'],
#  ['naive bayes classifiers',
#   'classifiers',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['naive bayes classifiers',
#   'classifiers',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['filesystem', 'operating systems', 'computer science', 'root'],
#  ['software development methods',
#   'software development',
#   'software project',
#   'software design',
#   'software engineering',
#   'computer science',
#   'root'],
#  ['continuous speech recognition',
#   'computational linguistics',
#   'database systems',
#   'computer systems',
#   'computer science',
#   'root'],
#  ['continuous speech recognition',
#   'computational linguistics',
#   'computer science',
#   'root'],
#  ['image search', 'search engines', 'root'],
#  ['dependency parser',
#   'natural language processing',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['dependency parser',
#   'natural language processing',
#   'computer science',
#   'root'],
#  ['dependency parser',
#   'natural language processing',
#   'computational linguistics',
#   'database systems',
#   'computer systems',
#   'computer science',
#   'root'],
#  ['dependency parser',
#   'natural language processing',
#   'computational linguistics',
#   'computer science',
#   'root'],
#  ['ambient intelligence',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['augmented reality systems',
#   'augmented reality',
#   'virtual reality',
#   'human computer interaction',
#   'computer science',
#   'root'],
#  ['augmented reality systems',
#   'augmented reality',
#   'virtual reality',
#   'simulation',
#   'root'],
#  ['machine translation systems',
#   'natural language processing',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['machine translation systems',
#   'natural language processing',
#   'computer science',
#   'root'],
#  ['machine translation systems',
#   'natural language processing',
#   'computational linguistics',
#   'database systems',
#   'computer systems',
#   'computer science',
#   'root'],
#  ['machine translation systems',
#   'natural language processing',
#   'computational linguistics',
#   'computer science',
#   'root'],
#  ['image encryption', 'cryptography', 'root'],
#  ['medical image processing',
#   'medical images',
#   'image analysis',
#   'computer imaging and vision',
#   'computer science',
#   'root'],
#  ['functional languages',
#   'functional programming',
#   'computer programming languages',
#   'computer programming',
#   'computer science',
#   'root'],
#  ['functional languages',
#   'functional programming',
#   'declarative programming',
#   'programming paradigm',
#   'root'],
#  ['functional languages',
#   'functional programming',
#   'declarative programming',
#   'computer programming',
#   'computer science',
#   'root'],
#  ['face detection',
#   'face recognition',
#   'pattern recognition',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['face detection',
#   'face recognition',
#   'pattern recognition',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['face detection',
#   'object recognition',
#   'pattern recognition',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['face detection',
#   'object recognition',
#   'pattern recognition',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['face detection', 'object recognition', 'recognition', 'root'],
#  ['anomaly detection', 'intrusion detection', 'root'],
#  ['object oriented design',
#   'software engineering',
#   'computer science',
#   'root'],
#  ['motion planning', 'mobile robots', 'robotics', 'computer science', 'root'],
#  ['video encoder', 'image compression', 'data compression', 'root'],
#  ['bioinformatics', 'computer science', 'root'],
#  ['bioinformatics', 'computational biology', 'root'],
#  ['recurrent neural networks',
#   'neural networks',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['recurrent neural networks',
#   'neural networks',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['home automation', 'smart homes', 'root'],
#  ['home automation', 'automation', 'root'],
#  ['microservices architecture',
#   'software architecture patterns',
#   'software architecture',
#   'software design',
#   'software engineering',
#   'computer science',
#   'root'],
#  ['microservices architecture',
#   'software architecture patterns',
#   'software architecture',
#   'software engineering',
#   'computer science',
#   'root'],
#  ['microservices architecture',
#   'software architecture patterns',
#   'software architecture',
#   'systems architecture',
#   'root'],
#  ['image authentication',
#   'digital watermarking',
#   'image processing',
#   'computer imaging and vision',
#   'computer science',
#   'root'],
#  ['image authentication',
#   'digital watermarking',
#   'image processing',
#   'signal processing',
#   'root'],
#  ['virtualization technologies',
#   'virtual machines',
#   'cloud computing',
#   'computer systems',
#   'computer science',
#   'root'],
#  ['virtualization technologies',
#   'virtual machines',
#   'cloud computing',
#   'service on Internet',
#   'e-service',
#   'root'],
#  ['virtualization technologies',
#   'virtual machines',
#   'cloud computing',
#   'service on Internet',
#   'network service',
#   'middleware of distributed system',
#   'middleware',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['virtualization technologies',
#   'virtual machines',
#   'cloud computing',
#   'computing platform',
#   'root'],
#  ['network management system',
#   'network management',
#   'network architecture',
#   'computer networks',
#   'computer science',
#   'root'],
#  ['java virtual machines',
#   'java',
#   'high level languages',
#   'computer programming',
#   'computer science',
#   'root'],
#  ['opinion mining',
#   'sentiment analysis',
#   'natural language processing',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['opinion mining',
#   'sentiment analysis',
#   'natural language processing',
#   'computer science',
#   'root'],
#  ['opinion mining',
#   'sentiment analysis',
#   'natural language processing',
#   'computational linguistics',
#   'database systems',
#   'computer systems',
#   'computer science',
#   'root'],
#  ['opinion mining',
#   'sentiment analysis',
#   'natural language processing',
#   'computational linguistics',
#   'computer science',
#   'root'],
#  ['opinion mining',
#   'sentiment analysis',
#   'affective computing',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['dimensionality reduction',
#   'pattern recognition',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['dimensionality reduction',
#   'pattern recognition',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['cognitive systems', 'artificial intelligence', 'computer science', 'root'],
#  ['bayesian inference',
#   'inference engines',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['supervised classification',
#   'image classification',
#   'imaging systems',
#   'root'],
#  ['supervised classification',
#   'image classification',
#   'image processing',
#   'computer imaging and vision',
#   'computer science',
#   'root'],
#  ['supervised classification',
#   'image classification',
#   'image processing',
#   'signal processing',
#   'root'],
#  ['supervised classification',
#   'image classification',
#   'classification',
#   'root'],
#  ['object detection',
#   'object recognition',
#   'pattern recognition',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['object detection',
#   'object recognition',
#   'pattern recognition',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['object detection', 'object recognition', 'recognition', 'root'],
#  ['object detection', 'computer vision', 'root'],
#  ['reactive programming',
#   'functional programming',
#   'computer programming languages',
#   'computer programming',
#   'computer science',
#   'root'],
#  ['reactive programming',
#   'functional programming',
#   'declarative programming',
#   'programming paradigm',
#   'root'],
#  ['reactive programming',
#   'functional programming',
#   'declarative programming',
#   'computer programming',
#   'computer science',
#   'root'],
#  ['reactive programming',
#   'dataflow programming',
#   'declarative programming',
#   'programming paradigm',
#   'root'],
#  ['reactive programming',
#   'dataflow programming',
#   'declarative programming',
#   'computer programming',
#   'computer science',
#   'root'],
#  ['database schemas',
#   'database systems',
#   'computer systems',
#   'computer science',
#   'root'],
#  ['text classification',
#   'text processing',
#   'natural language processing',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['text classification',
#   'text processing',
#   'natural language processing',
#   'computer science',
#   'root'],
#  ['text classification',
#   'text processing',
#   'natural language processing',
#   'computational linguistics',
#   'database systems',
#   'computer systems',
#   'computer science',
#   'root'],
#  ['text classification',
#   'text processing',
#   'natural language processing',
#   'computational linguistics',
#   'computer science',
#   'root'],
#  ['text classification', 'classification', 'root'],
#  ['knowledge visualization',
#   'information visualization',
#   'interactive computer graphics',
#   'user interfaces',
#   'human computer interaction',
#   'computer science',
#   'root'],
#  ['electronic document identification systems',
#   'authentication',
#   'verification',
#   'test',
#   'root'],
#  ['collaborative filtering algorithms',
#   'recommender systems',
#   'information retrieval',
#   'computer science',
#   'root'],
#  ['geo-spatial',
#   'geographic information system',
#   'software',
#   'computer science',
#   'root'],
#  ['geo-spatial',
#   'geographic information system',
#   'information system',
#   'system',
#   'root'],
#  ['geo-spatial',
#   'geographic information system',
#   'information system',
#   'software',
#   'computer science',
#   'root'],
#  ['geo-spatial',
#   'geographic information system',
#   'application',
#   'software',
#   'computer science',
#   'root'],
#  ['evolutionary algorithms',
#   'genetic algorithms',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['bibliographic retrieval systems', 'digital libraries', 'root'],
#  ['web crawlers', 'search engines', 'root'],
#  ['natural language understanding',
#   'natural language processing',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['natural language understanding',
#   'natural language processing',
#   'computer science',
#   'root'],
#  ['natural language understanding',
#   'natural language processing',
#   'computational linguistics',
#   'database systems',
#   'computer systems',
#   'computer science',
#   'root'],
#  ['natural language understanding',
#   'natural language processing',
#   'computational linguistics',
#   'computer science',
#   'root'],
#  ['communication network', 'computer networks', 'computer science', 'root'],
#  ['real time systems',
#   'knowledge based systems',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['smart contracts',
#   'distributed ledger',
#   'distributed database systems',
#   'root'],
#  ['smart contracts',
#   'distributed ledger',
#   'distributed data store',
#   'file system',
#   'data store',
#   'storage',
#   'root'],
#  ['smart contracts',
#   'distributed ledger',
#   'distributed data store',
#   'file system',
#   'filestore',
#   'data store',
#   'storage',
#   'root'],
#  ['smart contracts',
#   'distributed ledger',
#   'distributed data store',
#   'file system',
#   'filestore',
#   'software',
#   'computer science',
#   'root'],
#  ['smart contracts',
#   'distributed ledger',
#   'distributed data store',
#   'data store',
#   'storage',
#   'root'],
#  ['unsupervised learning',
#   'clustering algorithms',
#   'data mining',
#   'computer science',
#   'root'],
#  ['unsupervised learning', 'machine learning method', 'root'],
#  ['unsupervised learning',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['unsupervised learning', 'machine learning', 'computer science', 'root'],
#  ['cloud services', 'distributed database systems', 'root'],
#  ['distributed architecture',
#   'network architecture',
#   'computer networks',
#   'computer science',
#   'root'],
#  ['semi-supervised learning',
#   'weakly supervised learning',
#   'supervised learning',
#   'machine learning method',
#   'root'],
#  ['semi-supervised learning',
#   'weakly supervised learning',
#   'supervised learning',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['semi-supervised learning',
#   'weakly supervised learning',
#   'supervised learning',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['risk management tool', 'management tool', 'root'],
#  ['console application',
#   'application',
#   'software',
#   'computer science',
#   'root'],
#  ['video game development',
#   'software development',
#   'software project',
#   'software design',
#   'software engineering',
#   'computer science',
#   'root'],
#  ['telecommunications network', 'network', 'system', 'root'],
#  ['knowledge organization system', 'reference work', 'root'],
#  ['variational auto-encoder',
#   'autoencoder',
#   'artificial neural network',
#   'neural network',
#   'network',
#   'system',
#   'root'],
#  ['variational auto-encoder',
#   'autoencoder',
#   'artificial neural network',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['variational auto-encoder',
#   'autoencoder',
#   'artificial neural network',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['variational auto-encoder',
#   'autoencoder',
#   'artificial neural network',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['graph neural network', 'neural network', 'network', 'system', 'root'],
#  ['linear model', 'regression model', 'root'],
#  ['password manager',
#   'utility software',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['password manager',
#   'utility software',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['game server', 'server software', 'software', 'computer science', 'root'],
#  ['game server',
#   'server software',
#   'server',
#   'data processing system',
#   'information system',
#   'system',
#   'root'],
#  ['game server',
#   'server software',
#   'server',
#   'data processing system',
#   'information system',
#   'software',
#   'computer science',
#   'root'],
#  ['static program analysis', 'program analysis', 'root'],
#  ['payment system', 'financial system', 'root'],
#  ['integrated development environment',
#   'source code editor',
#   'programming tool',
#   'utility software',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['integrated development environment',
#   'source code editor',
#   'programming tool',
#   'utility software',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['integrated development environment',
#   'source code editor',
#   'text editor',
#   'editor',
#   'application',
#   'software',
#   'computer science',
#   'root'],
#  ['integrated development environment',
#   'source code editor',
#   'text editor',
#   'editor',
#   'interactive computing',
#   'software',
#   'computer science',
#   'root'],
#  ['integrated development environment',
#   'source code editor',
#   'text editor',
#   'application',
#   'software',
#   'computer science',
#   'root'],
#  ['integrated development environment',
#   'deployment environment',
#   'computer system',
#   'root'],
#  ['integrated development environment',
#   'programming tool',
#   'utility software',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['integrated development environment',
#   'programming tool',
#   'utility software',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['integrated development environment',
#   'application',
#   'software',
#   'computer science',
#   'root'],
#  ['algorithmic trading', 'electronic trading', 'root'],
#  ['business process automation', 'process automation', 'automation', 'root'],
#  ['test automation', 'automation', 'root'],
#  ['test automation', 'software', 'computer science', 'root'],
#  ['test automation', 'software testing', 'product testing', 'test', 'root'],
#  ['test automation', 'software testing', 'test', 'root'],
#  ['security testing',
#   'non-functional testing',
#   'product testing',
#   'test',
#   'root'],
#  ['security testing',
#   'non-functional testing',
#   'software testing',
#   'product testing',
#   'test',
#   'root'],
#  ['security testing',
#   'non-functional testing',
#   'software testing',
#   'test',
#   'root'],
#  ['code',
#   'rule-based system',
#   'knowledge-based system',
#   'information system',
#   'system',
#   'root'],
#  ['code',
#   'rule-based system',
#   'knowledge-based system',
#   'information system',
#   'software',
#   'computer science',
#   'root'],
#  ['web application security',
#   'application security',
#   'information security',
#   'security',
#   'root'],
#  ['malware analysis', 'reverse engineering', 'root'],
#  ['speech synthesis', 'sound synthesis', 'generative model', 'root'],
#  ['application performance management',
#   'IT performance management',
#   'information technology management',
#   'root'],
#  ['feature learning',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['feature learning', 'machine learning', 'computer science', 'root'],
#  ['convolutional neural network',
#   'feedforward neural network',
#   'neural networks',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['convolutional neural network',
#   'feedforward neural network',
#   'neural networks',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['convolutional neural network',
#   'feedforward neural network',
#   'artificial neural network',
#   'neural network',
#   'network',
#   'system',
#   'root'],
#  ['convolutional neural network',
#   'feedforward neural network',
#   'artificial neural network',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['convolutional neural network',
#   'feedforward neural network',
#   'artificial neural network',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['convolutional neural network',
#   'feedforward neural network',
#   'artificial neural network',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['software design pattern', 'design pattern', 'root'],
#  ['HTTP server',
#   'web server',
#   'server software',
#   'software',
#   'computer science',
#   'root'],
#  ['HTTP server',
#   'web server',
#   'server software',
#   'server',
#   'data processing system',
#   'information system',
#   'system',
#   'root'],
#  ['HTTP server',
#   'web server',
#   'server software',
#   'server',
#   'data processing system',
#   'information system',
#   'software',
#   'computer science',
#   'root'],
#  ['interpreter',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['microservices',
#   'service oriented architecture',
#   'software architecture',
#   'software design',
#   'software engineering',
#   'computer science',
#   'root'],
#  ['microservices',
#   'service oriented architecture',
#   'software architecture',
#   'software engineering',
#   'computer science',
#   'root'],
#  ['microservices',
#   'service oriented architecture',
#   'software architecture',
#   'systems architecture',
#   'root'],
#  ['regular expression', 'pattern matching', 'root'],
#  ['genetic algorithm', 'machine learning method', 'root'],
#  ['genetic algorithm',
#   'informed search algorithm',
#   'search algorithm',
#   'information retrieval',
#   'computer science',
#   'root'],
#  ['command-line interface',
#   'text-based user interface',
#   'user interface',
#   'root'],
#  ['command-line interface',
#   'text-based user interface',
#   'software',
#   'computer science',
#   'root'],
#  ['3D computer graphics', 'computer graphics', 'graphics', 'root'],
#  ['3D computer graphics',
#   'computer graphics',
#   'applied computer science',
#   'computer science',
#   'root'],
#  ['speech recognition',
#   'natural language processing',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['speech recognition',
#   'natural language processing',
#   'computer science',
#   'root'],
#  ['speech recognition',
#   'natural language processing',
#   'computational linguistics',
#   'database systems',
#   'computer systems',
#   'computer science',
#   'root'],
#  ['speech recognition',
#   'natural language processing',
#   'computational linguistics',
#   'computer science',
#   'root'],
#  ['speech recognition',
#   'sound recognition',
#   'automatic content recognition',
#   'root'],
#  ['speech recognition',
#   'computational linguistics',
#   'database systems',
#   'computer systems',
#   'computer science',
#   'root'],
#  ['speech recognition',
#   'computational linguistics',
#   'computer science',
#   'root'],
#  ['virtual machine', 'computing platform', 'root'],
#  ['virtual machine', 'application', 'software', 'computer science', 'root'],
#  ['virtual machine',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['embedded system',
#   'computer',
#   'IT system',
#   'information system',
#   'system',
#   'root'],
#  ['embedded system',
#   'computer',
#   'IT system',
#   'information system',
#   'software',
#   'computer science',
#   'root'],
#  ['embedded system', 'computer', 'computing platform', 'root'],
#  ['embedded system', 'computer', 'data terminal equipment', 'root'],
#  ['debugger',
#   'programming tool',
#   'utility software',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['debugger',
#   'programming tool',
#   'utility software',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['game engine',
#   'utility software',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['game engine',
#   'utility software',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['game engine',
#   'software engine',
#   'software framework',
#   'computing platform',
#   'root'],
#  ['game engine',
#   'software engine',
#   'software framework',
#   'software library',
#   'programming tool',
#   'utility software',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['game engine',
#   'software engine',
#   'software framework',
#   'software library',
#   'programming tool',
#   'utility software',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['game engine',
#   'software engine',
#   'software framework',
#   'software library',
#   'software component',
#   'root'],
#  ['game engine',
#   'software engine',
#   'software framework',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['game engine',
#   'software engine',
#   'software framework',
#   'computing infrastructure',
#   'root'],
#  ['game engine',
#   'middleware',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['data storage', 'information processing', 'root'],
#  ['data storage', 'storage', 'root'],
#  ['search engine', 'software', 'computer science', 'root'],
#  ['interface standard', 'communication system', 'root'],
#  ['blockchain', 'computer network protocol', 'root'],
#  ['blockchain', 'distributed ledger', 'distributed database systems', 'root'],
#  ['blockchain',
#   'distributed ledger',
#   'distributed data store',
#   'file system',
#   'data store',
#   'storage',
#   'root'],
#  ['blockchain',
#   'distributed ledger',
#   'distributed data store',
#   'file system',
#   'filestore',
#   'data store',
#   'storage',
#   'root'],
#  ['blockchain',
#   'distributed ledger',
#   'distributed data store',
#   'file system',
#   'filestore',
#   'software',
#   'computer science',
#   'root'],
#  ['blockchain',
#   'distributed ledger',
#   'distributed data store',
#   'data store',
#   'storage',
#   'root'],
#  ['blockchain', 'database', 'root'],
#  ['blockchain', 'data structure', 'software component', 'root'],
#  ['blockchain',
#   'distributed data store',
#   'file system',
#   'data store',
#   'storage',
#   'root'],
#  ['blockchain',
#   'distributed data store',
#   'file system',
#   'filestore',
#   'data store',
#   'storage',
#   'root'],
#  ['blockchain',
#   'distributed data store',
#   'file system',
#   'filestore',
#   'software',
#   'computer science',
#   'root'],
#  ['blockchain', 'distributed data store', 'data store', 'storage', 'root'],
#  ['multiplayer game', 'game', 'root'],
#  ['streaming media', 'data stream', 'root'],
#  ['genomics', 'computational biology', 'root'],
#  ['feature engineering', 'data pre-processing', 'root'],
#  ['neural machine translation',
#   'machine translation software',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['neural machine translation',
#   'statistical machine translation',
#   'machine translation',
#   'translation',
#   'root'],
#  ['neural machine translation',
#   'statistical machine translation',
#   'machine translation',
#   'computational linguistics',
#   'database systems',
#   'computer systems',
#   'computer science',
#   'root'],
#  ['neural machine translation',
#   'statistical machine translation',
#   'machine translation',
#   'computational linguistics',
#   'computer science',
#   'root'],
#  ['DevOps', 'software development methodology', 'root'],
#  ['generative adversarial network',
#   'generative artificial intelligence',
#   'artificial intelligence model',
#   'artificial neural network',
#   'neural network',
#   'network',
#   'system',
#   'root'],
#  ['generative adversarial network',
#   'generative artificial intelligence',
#   'artificial intelligence model',
#   'artificial neural network',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['generative adversarial network',
#   'generative artificial intelligence',
#   'artificial intelligence model',
#   'artificial neural network',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['generative adversarial network',
#   'generative artificial intelligence',
#   'artificial intelligence model',
#   'artificial neural network',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['generative adversarial network',
#   'generative artificial intelligence',
#   'artificial intelligence model',
#   'software',
#   'computer science',
#   'root'],
#  ['generative adversarial network',
#   'generative artificial intelligence',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['generative adversarial network', 'generative model', 'root'],
#  ['generative adversarial network',
#   'artificial neural network',
#   'neural network',
#   'network',
#   'system',
#   'root'],
#  ['generative adversarial network',
#   'artificial neural network',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['generative adversarial network',
#   'artificial neural network',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['generative adversarial network',
#   'artificial neural network',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['model-free reinforcement learning',
#   'reinforcement learning',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['model-free reinforcement learning',
#   'reinforcement learning',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['audio signal processing', 'signal processing', 'root'],
#  ['static program analysis tool',
#   'application',
#   'software',
#   'computer science',
#   'root'],
#  ['static program analysis tool',
#   'programming tool',
#   'utility software',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['static program analysis tool',
#   'programming tool',
#   'utility software',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['logging', 'software', 'computer science', 'root'],
#  ['data synchronization', 'data management', 'root'],
#  ['video processing',
#   'digital image processing',
#   'digital image storage',
#   'image compression',
#   'data compression',
#   'root'],
#  ['video processing',
#   'digital image processing',
#   'image processing',
#   'computer imaging and vision',
#   'computer science',
#   'root'],
#  ['video processing',
#   'digital image processing',
#   'image processing',
#   'signal processing',
#   'root'],
#  ['video processing',
#   'digital image processing',
#   'digital signal processing',
#   'signal processing',
#   'root'],
#  ['video processing', 'signal processing', 'root'],
#  ['graphics engine',
#   'software engine',
#   'software framework',
#   'computing platform',
#   'root'],
#  ['graphics engine',
#   'software engine',
#   'software framework',
#   'software library',
#   'programming tool',
#   'utility software',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['graphics engine',
#   'software engine',
#   'software framework',
#   'software library',
#   'programming tool',
#   'utility software',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['graphics engine',
#   'software engine',
#   'software framework',
#   'software library',
#   'software component',
#   'root'],
#  ['graphics engine',
#   'software engine',
#   'software framework',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['graphics engine',
#   'software engine',
#   'software framework',
#   'computing infrastructure',
#   'root'],
#  ['web browser engine',
#   'software engine',
#   'software framework',
#   'computing platform',
#   'root'],
#  ['web browser engine',
#   'software engine',
#   'software framework',
#   'software library',
#   'programming tool',
#   'utility software',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['web browser engine',
#   'software engine',
#   'software framework',
#   'software library',
#   'programming tool',
#   'utility software',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['web browser engine',
#   'software engine',
#   'software framework',
#   'software library',
#   'software component',
#   'root'],
#  ['web browser engine',
#   'software engine',
#   'software framework',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['web browser engine',
#   'software engine',
#   'software framework',
#   'computing infrastructure',
#   'root'],
#  ['web browser engine',
#   'rendering software',
#   'graphics software',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['web browser engine',
#   'rendering software',
#   'graphics software',
#   'application',
#   'software',
#   'computer science',
#   'root'],
#  ['web browser engine',
#   'rendering software',
#   'graphics software',
#   'editor',
#   'application',
#   'software',
#   'computer science',
#   'root'],
#  ['web browser engine',
#   'rendering software',
#   'graphics software',
#   'editor',
#   'interactive computing',
#   'software',
#   'computer science',
#   'root'],
#  ['image captioning',
#   'automatic image annotation',
#   'image annotation',
#   'root'],
#  ['serverless computing', 'execution model', 'root'],
#  ['serverless computing',
#   'applications architecture',
#   'information technology architecture',
#   'enterprise architecture',
#   'software architecture',
#   'software design',
#   'software engineering',
#   'computer science',
#   'root'],
#  ['serverless computing',
#   'applications architecture',
#   'information technology architecture',
#   'enterprise architecture',
#   'software architecture',
#   'software engineering',
#   'computer science',
#   'root'],
#  ['serverless computing',
#   'applications architecture',
#   'information technology architecture',
#   'enterprise architecture',
#   'software architecture',
#   'systems architecture',
#   'root'],
#  ['serverless computing',
#   'cloud computing',
#   'computer systems',
#   'computer science',
#   'root'],
#  ['serverless computing',
#   'cloud computing',
#   'service on Internet',
#   'e-service',
#   'root'],
#  ['serverless computing',
#   'cloud computing',
#   'service on Internet',
#   'network service',
#   'middleware of distributed system',
#   'middleware',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['serverless computing', 'cloud computing', 'computing platform', 'root'],
#  ['distributed system', 'computer system', 'root'],
#  ['automated machine learning',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['automated machine learning',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['image scaling',
#   'sample-rate conversion',
#   'digital signal processing',
#   'signal processing',
#   'root'],
#  ['image scaling',
#   'digital image processing',
#   'digital image storage',
#   'image compression',
#   'data compression',
#   'root'],
#  ['image scaling',
#   'digital image processing',
#   'image processing',
#   'computer imaging and vision',
#   'computer science',
#   'root'],
#  ['image scaling',
#   'digital image processing',
#   'image processing',
#   'signal processing',
#   'root'],
#  ['image scaling',
#   'digital image processing',
#   'digital signal processing',
#   'signal processing',
#   'root'],
#  ['Web content management system',
#   'content management system',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['Web content management system',
#   'content management system',
#   'software',
#   'computer science',
#   'root'],
#  ['Web content management system',
#   'content management system',
#   'management system',
#   'root'],
#  ['web crawler',
#   'Internet bot',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['activity recognition', 'computer science', 'root'],
#  ['compiler',
#   'build tool',
#   'programming tool',
#   'utility software',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['compiler',
#   'build tool',
#   'programming tool',
#   'utility software',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['IRC bot',
#   'Internet bot',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['deep neural network',
#   'artificial neural network',
#   'neural network',
#   'network',
#   'system',
#   'root'],
#  ['deep neural network',
#   'artificial neural network',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['deep neural network',
#   'artificial neural network',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['deep neural network',
#   'artificial neural network',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['digital security', 'information security', 'security', 'root'],
#  ['edge computing',
#   'distributed computing',
#   'parallel computing',
#   'concurrent computing',
#   'computer programming',
#   'computer science',
#   'root'],
#  ['edge computing', 'distributed computing', 'computer science', 'root'],
#  ['Integrated software', 'software', 'computer science', 'root'],
#  ['deep reinforcement learning',
#   'deep learning',
#   'neural networks',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['deep reinforcement learning',
#   'deep learning',
#   'neural networks',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['deep reinforcement learning',
#   'deep learning',
#   'machine learning method',
#   'root'],
#  ['deep reinforcement learning',
#   'reinforcement learning',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['deep reinforcement learning',
#   'reinforcement learning',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['recommender system',
#   'information filtering system',
#   'information system',
#   'system',
#   'root'],
#  ['recommender system',
#   'information filtering system',
#   'information system',
#   'software',
#   'computer science',
#   'root'],
#  ['graph database',
#   'database management system',
#   'software system',
#   'software',
#   'computer science',
#   'root'],
#  ['graph database', 'database', 'root'],
#  ['transfer learning',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['transfer learning', 'machine learning', 'computer science', 'root'],
#  ['web browser', 'application', 'software', 'computer science', 'root'],
#  ['web browser', 'computing platform', 'root'],
#  ['web browser',
#   'HTTP client',
#   'client',
#   'software',
#   'computer science',
#   'root'],
#  ['web browser',
#   'browser',
#   'utility software',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['web browser',
#   'browser',
#   'utility software',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['distributed multimedia communications platform',
#   'computing platform',
#   'root'],
#  ['distributed multimedia communications platform',
#   'instant messaging',
#   'software',
#   'computer science',
#   'root'],
#  ['distributed multimedia communications platform',
#   'instant messaging',
#   'remote communication',
#   'root'],
#  ['distributed multimedia communications platform',
#   'softphone',
#   'application',
#   'software',
#   'computer science',
#   'root'],
#  ['long short-term memory',
#   'recurrent neural network',
#   'artificial neural network',
#   'neural network',
#   'network',
#   'system',
#   'root'],
#  ['long short-term memory',
#   'recurrent neural network',
#   'artificial neural network',
#   'machine learning',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['long short-term memory',
#   'recurrent neural network',
#   'artificial neural network',
#   'machine learning',
#   'computer science',
#   'root'],
#  ['long short-term memory',
#   'recurrent neural network',
#   'artificial neural network',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['misuse detection', 'security management', 'root'],
#  ['autonomous car', 'autonomous vehicle', 'root'],
#  ['database administration', 'data management', 'root'],
#  ['database administration',
#   'system administration',
#   'systems management',
#   'information technology management',
#   'root'],
#  ['audio player software',
#   'media player software',
#   'multimedia software',
#   'application',
#   'software',
#   'computer science',
#   'root'],
#  ['electronic trading platform',
#   'application',
#   'software',
#   'computer science',
#   'root'],
#  ['static site generator',
#   'web framework',
#   'software framework',
#   'computing platform',
#   'root'],
#  ['static site generator',
#   'web framework',
#   'software framework',
#   'software library',
#   'programming tool',
#   'utility software',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['static site generator',
#   'web framework',
#   'software framework',
#   'software library',
#   'programming tool',
#   'utility software',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['static site generator',
#   'web framework',
#   'software framework',
#   'software library',
#   'software component',
#   'root'],
#  ['static site generator',
#   'web framework',
#   'software framework',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['static site generator',
#   'web framework',
#   'software framework',
#   'computing infrastructure',
#   'root'],
#  ['static site generator',
#   'web template system',
#   'desktop publishing software',
#   'editor',
#   'application',
#   'software',
#   'computer science',
#   'root'],
#  ['static site generator',
#   'web template system',
#   'desktop publishing software',
#   'editor',
#   'interactive computing',
#   'software',
#   'computer science',
#   'root'],
#  ['static site generator',
#   'web template system',
#   'desktop publishing software',
#   'publishing software',
#   'software',
#   'computer science',
#   'root'],
#  ['static site generator',
#   'web template system',
#   'desktop publishing software',
#   'graphics software',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['static site generator',
#   'web template system',
#   'desktop publishing software',
#   'graphics software',
#   'application',
#   'software',
#   'computer science',
#   'root'],
#  ['static site generator',
#   'web template system',
#   'desktop publishing software',
#   'graphics software',
#   'editor',
#   'application',
#   'software',
#   'computer science',
#   'root'],
#  ['static site generator',
#   'web template system',
#   'desktop publishing software',
#   'graphics software',
#   'editor',
#   'interactive computing',
#   'software',
#   'computer science',
#   'root'],
#  ['graphical user interface',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['graphical user interface', 'user interface', 'root'],
#  ['video game', 'application', 'software', 'computer science', 'root'],
#  ['video game', 'electronic game', 'game', 'root'],
#  ['video game',
#   'entertainment software',
#   'software',
#   'computer science',
#   'root'],
#  ['object-oriented programming',
#   'structured programming',
#   'programming paradigm',
#   'root'],
#  ['naive Bayes classifier', 'Bayes classifier', 'root'],
#  ['chatbot',
#   'software agent',
#   'computer program',
#   'program',
#   'software',
#   'computer science',
#   'root'],
#  ['chatbot',
#   'software agent',
#   'artificially intelligent entity',
#   'agent',
#   'root'],
#  ['package management system', 'management system', 'root'],
#  ['package management system',
#   'digital distribution platform',
#   'online database',
#   'website',
#   'digital media',
#   'root'],
#  ['package management system',
#   'digital distribution platform',
#   'online database',
#   'website',
#   'software',
#   'computer science',
#   'root'],
#  ['package management system',
#   'digital distribution platform',
#   'online database',
#   'website',
#   'online service',
#   'service on Internet',
#   'e-service',
#   'root'],
#  ['package management system',
#   'digital distribution platform',
#   'online database',
#   'website',
#   'online service',
#   'service on Internet',
#   'network service',
#   'middleware of distributed system',
#   'middleware',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['package management system',
#   'digital distribution platform',
#   'online database',
#   'online service',
#   'service on Internet',
#   'e-service',
#   'root'],
#  ['package management system',
#   'digital distribution platform',
#   'online database',
#   'online service',
#   'service on Internet',
#   'network service',
#   'middleware of distributed system',
#   'middleware',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['package management system',
#   'digital distribution platform',
#   'online database',
#   'database',
#   'root'],
#  ['package management system',
#   'digital distribution platform',
#   'file hosting service',
#   'root'],
#  ['package management system', 'software', 'computer science', 'root'],
#  ['unit testing', 'software testing', 'product testing', 'test', 'root'],
#  ['unit testing', 'software testing', 'test', 'root'],
#  ['operating system',
#   'system software',
#   'software',
#   'computer science',
#   'root'],
#  ['operating system', 'computing platform', 'root'],
#  ['telecommunications application',
#   'application',
#   'software',
#   'computer science',
#   'root'],
#  ['medical imaging', 'medical diagnosis', 'root'],
#  ['Topic modeling',
#   'text mining',
#   'text processing',
#   'natural language processing',
#   'artificial intelligence',
#   'computer science',
#   'root'],
#  ['Topic modeling',
#   'text mining',
#   'text processing',
#   'natural language processing',
#   'computer science',
#   'root'],
#  ['Topic modeling',
#   'text mining',
#   'text processing',
#   'natural language processing',
#   'computational linguistics',
#   'database systems',
#   'computer systems',
#   'computer science',
#   'root'],
#  ['Topic modeling',
#   'text mining',
#   'text processing',
#   'natural language processing',
#   'computational linguistics',
#   'computer science',
#   'root'],
#  ['continuous integration', 'computing platform', 'root'],
#  ['kernel', 'operating system component', 'software component', 'root'],
#  ['distributed database', 'database', 'root']]

# %%
wiki_taxonomy = Taxonomy.load(f'../data/interim/new_gitranking_wikidata.json')
wiki_edges = [(pair[0], pair[1]) for pair in wiki_taxonomy.pairs]
removed_nodes = []
for node in g:
    inwards = g.in_edges(node)
    outwards = g.out_edges(node)
    both_edges = list(inwards) + list(outwards)
    #if all(edge in wiki_edges for edge in both_edges):
    t = list(flatten(paths_passing_throught_node[node]))
    print(t)
    if not set(t).intersection(set(gitranking.terms)):
        removed_nodes.append(node)
# Out:
# ['evolutionary algorithms', 'genetic algorithms', 'artificial intelligence', 'computer science', 'root']
# ['optical character recognition', 'character recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'optical character recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'relation extraction', 'information extraction', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'emotion recognition', 'face recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'data clustering', 'cluster analysis', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'question answering', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'natural language generation', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'support vector machine', 'classifiers', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'support vector machine', 'supervised learning', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'naive bayes classifiers', 'classifiers', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'dependency parser', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'ambient intelligence', 'artificial intelligence', 'computer science', 'root', 'machine translation systems', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'face detection', 'face recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'face detection', 'object recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'recurrent neural networks', 'neural networks', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'opinion mining', 'sentiment analysis', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'opinion mining', 'sentiment analysis', 'affective computing', 'artificial intelligence', 'computer science', 'root', 'dimensionality reduction', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'cognitive systems', 'artificial intelligence', 'computer science', 'root', 'bayesian inference', 'inference engines', 'artificial intelligence', 'computer science', 'root', 'object detection', 'object recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'text classification', 'text processing', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'evolutionary algorithms', 'genetic algorithms', 'artificial intelligence', 'computer science', 'root', 'natural language understanding', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'real time systems', 'knowledge based systems', 'artificial intelligence', 'computer science', 'root', 'unsupervised learning', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'semi-supervised learning', 'weakly supervised learning', 'supervised learning', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'variational auto-encoder', 'autoencoder', 'artificial neural network', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'variational auto-encoder', 'autoencoder', 'artificial neural network', 'artificial intelligence', 'computer science', 'root', 'feature learning', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'convolutional neural network', 'feedforward neural network', 'neural networks', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'convolutional neural network', 'feedforward neural network', 'artificial neural network', 'machine learning', 'artifici ...
# ['network security', 'computer networks', 'computer science', 'root', 'network security', 'computer security', 'computer science', 'root', 'network security', 'computer security', 'information security', 'security', 'root', 'network security', 'computer security', 'security', 'root']
# ['network security', 'computer networks', 'computer science', 'root', 'network management system', 'network management', 'network architecture', 'computer networks', 'computer science', 'root', 'communication network', 'computer networks', 'computer science', 'root', 'distributed architecture', 'network architecture', 'computer networks', 'computer science', 'root']
# ['iot', 'architecture types', 'software architecture', 'software design', 'software engineering', 'computer science', 'root', 'iot', 'architecture types', 'software architecture', 'software engineering', 'computer science', 'root', 'iot', 'architecture types', 'software architecture', 'systems architecture', 'root']
# ['iot', 'architecture types', 'software architecture', 'software design', 'software engineering', 'computer science', 'root', 'iot', 'architecture types', 'software architecture', 'software engineering', 'computer science', 'root', 'iot', 'architecture types', 'software architecture', 'systems architecture', 'root']
# ['medical image processing', 'medical images', 'image analysis', 'computer imaging and vision', 'computer science', 'root']
# ['image segmentation', 'image analysis', 'computer imaging and vision', 'computer science', 'root', 'medical image processing', 'medical images', 'image analysis', 'computer imaging and vision', 'computer science', 'root']
# ['optical character recognition', 'character recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'optical character recognition', 'character recognition', 'pattern recognition', 'machine learning', 'computer science', 'root', 'optical character recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'optical character recognition', 'pattern recognition', 'machine learning', 'computer science', 'root']
# ['optical character recognition', 'character recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'optical character recognition', 'character recognition', 'pattern recognition', 'machine learning', 'computer science', 'root']
# ['knowledge visualization', 'information visualization', 'interactive computer graphics', 'user interfaces', 'human computer interaction', 'computer science', 'root']
# ['knowledge visualization', 'information visualization', 'interactive computer graphics', 'user interfaces', 'human computer interaction', 'computer science', 'root']
# ['parallel processing systems', 'distributed systems', 'distributed computer systems', 'computer systems', 'computer science', 'root']
# ['parallel processing systems', 'distributed systems', 'distributed computer systems', 'computer systems', 'computer science', 'root']
# ['video processing', 'digital image processing', 'digital image storage', 'image compression', 'data compression', 'root', 'video processing', 'digital image processing', 'image processing', 'computer imaging and vision', 'computer science', 'root', 'video processing', 'digital image processing', 'image processing', 'signal processing', 'root', 'video processing', 'digital image processing', 'digital signal processing', 'signal processing', 'root', 'image scaling', 'digital image processing', 'digital image storage', 'image compression', 'data compression', 'root', 'image scaling', 'digital image processing', 'image processing', 'computer imaging and vision', 'computer science', 'root', 'image scaling', 'digital image processing', 'image processing', 'signal processing', 'root', 'image scaling', 'digital image processing', 'digital signal processing', 'signal processing', 'root']
# ['video processing', 'digital image processing', 'digital image storage', 'image compression', 'data compression', 'root', 'image scaling', 'digital image processing', 'digital image storage', 'image compression', 'data compression', 'root']
# ['relation extraction', 'information extraction', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'relation extraction', 'information extraction', 'natural language processing', 'computer science', 'root', 'relation extraction', 'information extraction', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'relation extraction', 'information extraction', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'relation extraction', 'information extraction', 'information retrieval', 'computer science', 'root']
# ['relation extraction', 'information extraction', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'relation extraction', 'information extraction', 'natural language processing', 'computer science', 'root', 'relation extraction', 'information extraction', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'relation extraction', 'information extraction', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'relation extraction', 'information extraction', 'information retrieval', 'computer science', 'root']
# ['theoretical computer science', 'computer science', 'root']
# ['network security', 'computer networks', 'computer science', 'root', 'network security', 'computer security', 'computer science', 'root', 'iot', 'architecture types', 'software architecture', 'software design', 'software engineering', 'computer science', 'root', 'iot', 'architecture types', 'software architecture', 'software engineering', 'computer science', 'root', 'optical character recognition', 'character recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'optical character recognition', 'character recognition', 'pattern recognition', 'machine learning', 'computer science', 'root', 'optical character recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'optical character recognition', 'pattern recognition', 'machine learning', 'computer science', 'root', 'parallel processing systems', 'distributed systems', 'distributed computer systems', 'computer systems', 'computer science', 'root', 'relation extraction', 'information extraction', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'relation extraction', 'information extraction', 'natural language processing', 'computer science', 'root', 'relation extraction', 'information extraction', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'relation extraction', 'information extraction', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'relation extraction', 'information extraction', 'information retrieval', 'computer science', 'root', 'theoretical computer science', 'computer science', 'root', 'emotion recognition', 'face recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'emotion recognition', 'face recognition', 'pattern recognition', 'machine learning', 'computer science', 'root', 'data clustering', 'cluster analysis', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'data clustering', 'cluster analysis', 'machine learning', 'computer science', 'root', 'data clustering', 'cluster analysis', 'data mining', 'computer science', 'root', 'three dimensional computer graphics', 'computer imaging and vision', 'computer science', 'root', 'question answering', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'question answering', 'natural language processing', 'computer science', 'root', 'question answering', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'question answering', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'question answering', 'computer program', 'program', 'software', 'computer science', 'root', 'natural language generation', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'natural language generation', 'natural language processing', 'computer science', 'root', 'natural language generation', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'natural language generation', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'program debugging', 'software quality', 'software design', 'software engineering', 'computer science', 'root', 'support vector machine', 'classifiers', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'support vector machine', 'classifiers', 'machine learning', 'computer science', 'root', 'support vector machine', 'supervised learning', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'support vector machine', 'supervised learning', 'machine learning', 'computer science', 'root', 'mobile application development', 'software development' ...
# ['emotion recognition', 'face recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'emotion recognition', 'face recognition', 'pattern recognition', 'machine learning', 'computer science', 'root', 'emotion recognition', 'recognition', 'root']
# ['emotion recognition', 'face recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'emotion recognition', 'face recognition', 'pattern recognition', 'machine learning', 'computer science', 'root', 'face detection', 'face recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'face detection', 'face recognition', 'pattern recognition', 'machine learning', 'computer science', 'root']
# ['relation extraction', 'information extraction', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'relation extraction', 'information extraction', 'natural language processing', 'computer science', 'root', 'relation extraction', 'information extraction', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'relation extraction', 'information extraction', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'question answering', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'question answering', 'natural language processing', 'computer science', 'root', 'question answering', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'question answering', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'natural language generation', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'natural language generation', 'natural language processing', 'computer science', 'root', 'natural language generation', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'natural language generation', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'dependency parser', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'dependency parser', 'natural language processing', 'computer science', 'root', 'dependency parser', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'dependency parser', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'machine translation systems', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'machine translation systems', 'natural language processing', 'computer science', 'root', 'machine translation systems', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'machine translation systems', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'opinion mining', 'sentiment analysis', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'opinion mining', 'sentiment analysis', 'natural language processing', 'computer science', 'root', 'opinion mining', 'sentiment analysis', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'opinion mining', 'sentiment analysis', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'text classification', 'text processing', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'text classification', 'text processing', 'natural language processing', 'computer science', 'root', 'text classification', 'text processing', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'text classification', 'text processing', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'natural language understanding', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'natural language understanding', 'natural language processing', 'computer science', 'root', 'natural language understanding', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'natural language understanding', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'speech recognition', 'natural  ...
# ['video encoder', 'image compression', 'data compression', 'root', 'video processing', 'digital image processing', 'digital image storage', 'image compression', 'data compression', 'root', 'image scaling', 'digital image processing', 'digital image storage', 'image compression', 'data compression', 'root']
# ['functional languages', 'functional programming', 'computer programming languages', 'computer programming', 'computer science', 'root', 'reactive programming', 'functional programming', 'computer programming languages', 'computer programming', 'computer science', 'root']
# ['functional languages', 'functional programming', 'computer programming languages', 'computer programming', 'computer science', 'root', 'functional languages', 'functional programming', 'declarative programming', 'computer programming', 'computer science', 'root', 'java virtual machines', 'java', 'high level languages', 'computer programming', 'computer science', 'root', 'reactive programming', 'functional programming', 'computer programming languages', 'computer programming', 'computer science', 'root', 'reactive programming', 'functional programming', 'declarative programming', 'computer programming', 'computer science', 'root', 'reactive programming', 'dataflow programming', 'declarative programming', 'computer programming', 'computer science', 'root', 'edge computing', 'distributed computing', 'parallel computing', 'concurrent computing', 'computer programming', 'computer science', 'root']
# ['augmented reality systems', 'augmented reality', 'virtual reality', 'human computer interaction', 'computer science', 'root', 'augmented reality systems', 'augmented reality', 'virtual reality', 'simulation', 'root']
# ['augmented reality systems', 'augmented reality', 'virtual reality', 'human computer interaction', 'computer science', 'root', 'augmented reality systems', 'augmented reality', 'virtual reality', 'simulation', 'root']
# ['augmented reality systems', 'augmented reality', 'virtual reality', 'human computer interaction', 'computer science', 'root', 'knowledge visualization', 'information visualization', 'interactive computer graphics', 'user interfaces', 'human computer interaction', 'computer science', 'root']
# ['data clustering', 'cluster analysis', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'data clustering', 'cluster analysis', 'machine learning', 'computer science', 'root', 'data clustering', 'cluster analysis', 'data analysis', 'root', 'data clustering', 'cluster analysis', 'data mining', 'computer science', 'root']
# ['data clustering', 'cluster analysis', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'data clustering', 'cluster analysis', 'machine learning', 'computer science', 'root', 'data clustering', 'cluster analysis', 'data analysis', 'root', 'data clustering', 'cluster analysis', 'data mining', 'computer science', 'root']
# ['filesystem', 'operating systems', 'computer science', 'root']
# ['three dimensional computer graphics', 'computer imaging and vision', 'computer science', 'root']
# ['three dimensional computer graphics', 'computer imaging and vision', 'computer science', 'root', 'image segmentation', 'image analysis', 'computer imaging and vision', 'computer science', 'root', 'medical image processing', 'medical images', 'image analysis', 'computer imaging and vision', 'computer science', 'root', 'image authentication', 'digital watermarking', 'image processing', 'computer imaging and vision', 'computer science', 'root', 'supervised classification', 'image classification', 'image processing', 'computer imaging and vision', 'computer science', 'root', 'video processing', 'digital image processing', 'image processing', 'computer imaging and vision', 'computer science', 'root', 'image scaling', 'digital image processing', 'image processing', 'computer imaging and vision', 'computer science', 'root']
# ['unscented kalman filter', 'kalman filters', 'signal processing', 'root']
# ['unscented kalman filter', 'kalman filters', 'signal processing', 'root']
# ['question answering', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'question answering', 'natural language processing', 'computer science', 'root', 'question answering', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'question answering', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'question answering', 'computer program', 'program', 'software', 'computer science', 'root', 'question answering', 'natural-language user interface', 'voice user interface', 'user interface', 'root']
# ['natural language generation', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'natural language generation', 'natural language processing', 'computer science', 'root', 'natural language generation', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'natural language generation', 'natural language processing', 'computational linguistics', 'computer science', 'root']
# ['program debugging', 'software quality', 'software design', 'software engineering', 'computer science', 'root']
# ['program debugging', 'software quality', 'software design', 'software engineering', 'computer science', 'root']
# ['support vector machine', 'classifiers', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'support vector machine', 'classifiers', 'machine learning', 'computer science', 'root', 'support vector machine', 'classification algorithm', 'root', 'support vector machine', 'supervised learning', 'machine learning method', 'root', 'support vector machine', 'supervised learning', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'support vector machine', 'supervised learning', 'machine learning', 'computer science', 'root']
# ['support vector machine', 'classifiers', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'support vector machine', 'classifiers', 'machine learning', 'computer science', 'root', 'naive bayes classifiers', 'classifiers', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'naive bayes classifiers', 'classifiers', 'machine learning', 'computer science', 'root']
# ['relation extraction', 'information extraction', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'question answering', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'natural language generation', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'continuous speech recognition', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'dependency parser', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'machine translation systems', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'opinion mining', 'sentiment analysis', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'database schemas', 'database systems', 'computer systems', 'computer science', 'root', 'text classification', 'text processing', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'natural language understanding', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'speech recognition', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'speech recognition', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'neural machine translation', 'statistical machine translation', 'machine translation', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'Topic modeling', 'text mining', 'text processing', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root']
# ['parallel processing systems', 'distributed systems', 'distributed computer systems', 'computer systems', 'computer science', 'root', 'relation extraction', 'information extraction', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'question answering', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'natural language generation', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'telecommunication systems', 'computer systems', 'computer science', 'root', 'continuous speech recognition', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'dependency parser', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'machine translation systems', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'virtualization technologies', 'virtual machines', 'cloud computing', 'computer systems', 'computer science', 'root', 'opinion mining', 'sentiment analysis', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'database schemas', 'database systems', 'computer systems', 'computer science', 'root', 'text classification', 'text processing', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'natural language understanding', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'speech recognition', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'speech recognition', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'neural machine translation', 'statistical machine translation', 'machine translation', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'serverless computing', 'cloud computing', 'computer systems', 'computer science', 'root', 'Topic modeling', 'text mining', 'text processing', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root']
# ['mobile application development', 'mobile applications', 'root', 'mobile application development', 'software development', 'software project', 'software design', 'software engineering', 'computer science', 'root']
# ['mobile application development', 'mobile applications', 'root']
# ['functional languages', 'functional programming', 'computer programming languages', 'computer programming', 'computer science', 'root', 'functional languages', 'functional programming', 'declarative programming', 'programming paradigm', 'root', 'functional languages', 'functional programming', 'declarative programming', 'computer programming', 'computer science', 'root', 'reactive programming', 'functional programming', 'computer programming languages', 'computer programming', 'computer science', 'root', 'reactive programming', 'functional programming', 'declarative programming', 'programming paradigm', 'root', 'reactive programming', 'functional programming', 'declarative programming', 'computer programming', 'computer science', 'root']
# ['iot', 'architecture types', 'software architecture', 'software design', 'software engineering', 'computer science', 'root', 'iot', 'architecture types', 'software architecture', 'software engineering', 'computer science', 'root', 'iot', 'architecture types', 'software architecture', 'systems architecture', 'root', 'microservices architecture', 'software architecture patterns', 'software architecture', 'software design', 'software engineering', 'computer science', 'root', 'microservices architecture', 'software architecture patterns', 'software architecture', 'software engineering', 'computer science', 'root', 'microservices architecture', 'software architecture patterns', 'software architecture', 'systems architecture', 'root', 'microservices', 'service oriented architecture', 'software architecture', 'software design', 'software engineering', 'computer science', 'root', 'microservices', 'service oriented architecture', 'software architecture', 'software engineering', 'computer science', 'root', 'microservices', 'service oriented architecture', 'software architecture', 'systems architecture', 'root', 'serverless computing', 'applications architecture', 'information technology architecture', 'enterprise architecture', 'software architecture', 'software design', 'software engineering', 'computer science', 'root', 'serverless computing', 'applications architecture', 'information technology architecture', 'enterprise architecture', 'software architecture', 'software engineering', 'computer science', 'root', 'serverless computing', 'applications architecture', 'information technology architecture', 'enterprise architecture', 'software architecture', 'systems architecture', 'root']
# ['iot', 'architecture types', 'software architecture', 'software design', 'software engineering', 'computer science', 'root', 'program debugging', 'software quality', 'software design', 'software engineering', 'computer science', 'root', 'mobile application development', 'software development', 'software project', 'software design', 'software engineering', 'computer science', 'root', 'software development methods', 'software development', 'software project', 'software design', 'software engineering', 'computer science', 'root', 'microservices architecture', 'software architecture patterns', 'software architecture', 'software design', 'software engineering', 'computer science', 'root', 'video game development', 'software development', 'software project', 'software design', 'software engineering', 'computer science', 'root', 'microservices', 'service oriented architecture', 'software architecture', 'software design', 'software engineering', 'computer science', 'root', 'serverless computing', 'applications architecture', 'information technology architecture', 'enterprise architecture', 'software architecture', 'software design', 'software engineering', 'computer science', 'root']
# ['image segmentation', 'image analysis', 'computer imaging and vision', 'computer science', 'root', 'image segmentation', 'computer vision', 'root']
# ['smart contracts', 'distributed ledger', 'distributed database systems', 'root', 'smart contracts', 'distributed ledger', 'distributed data store', 'file system', 'data store', 'storage', 'root', 'smart contracts', 'distributed ledger', 'distributed data store', 'file system', 'filestore', 'data store', 'storage', 'root', 'smart contracts', 'distributed ledger', 'distributed data store', 'file system', 'filestore', 'software', 'computer science', 'root', 'smart contracts', 'distributed ledger', 'distributed data store', 'data store', 'storage', 'root', 'blockchain', 'distributed ledger', 'distributed database systems', 'root', 'blockchain', 'distributed ledger', 'distributed data store', 'file system', 'data store', 'storage', 'root', 'blockchain', 'distributed ledger', 'distributed data store', 'file system', 'filestore', 'data store', 'storage', 'root', 'blockchain', 'distributed ledger', 'distributed data store', 'file system', 'filestore', 'software', 'computer science', 'root', 'blockchain', 'distributed ledger', 'distributed data store', 'data store', 'storage', 'root']
# ['smart contracts', 'distributed ledger', 'distributed database systems', 'root', 'cloud services', 'distributed database systems', 'root', 'blockchain', 'distributed ledger', 'distributed database systems', 'root']
# ['web development', 'web application', 'website', 'digital media', 'root', 'web development', 'web application', 'website', 'software', 'computer science', 'root', 'web development', 'web application', 'website', 'online service', 'service on Internet', 'e-service', 'root', 'web development', 'web application', 'website', 'online service', 'service on Internet', 'network service', 'middleware of distributed system', 'middleware', 'system software', 'software', 'computer science', 'root', 'web development', 'web application', 'Internet application', 'application', 'software', 'computer science', 'root']
# ['web development', 'web application', 'website', 'digital media', 'root', 'web development', 'web application', 'website', 'software', 'computer science', 'root', 'web development', 'web application', 'website', 'online service', 'service on Internet', 'e-service', 'root', 'web development', 'web application', 'website', 'online service', 'service on Internet', 'network service', 'middleware of distributed system', 'middleware', 'system software', 'software', 'computer science', 'root', 'web development', 'web application', 'Internet application', 'application', 'software', 'computer science', 'root']
# ['unsupervised learning', 'clustering algorithms', 'data mining', 'computer science', 'root']
# ['data clustering', 'cluster analysis', 'data mining', 'computer science', 'root', 'data analytics', 'data mining', 'computer science', 'root', 'decision trees', 'data mining', 'computer science', 'root', 'unsupervised learning', 'clustering algorithms', 'data mining', 'computer science', 'root']
# ['model-free reinforcement learning', 'reinforcement learning', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'model-free reinforcement learning', 'reinforcement learning', 'machine learning', 'computer science', 'root', 'deep reinforcement learning', 'reinforcement learning', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'deep reinforcement learning', 'reinforcement learning', 'machine learning', 'computer science', 'root']
# ['optical character recognition', 'character recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'optical character recognition', 'character recognition', 'pattern recognition', 'machine learning', 'computer science', 'root', 'optical character recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'optical character recognition', 'pattern recognition', 'machine learning', 'computer science', 'root', 'emotion recognition', 'face recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'emotion recognition', 'face recognition', 'pattern recognition', 'machine learning', 'computer science', 'root', 'data clustering', 'cluster analysis', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'data clustering', 'cluster analysis', 'machine learning', 'computer science', 'root', 'support vector machine', 'classifiers', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'support vector machine', 'classifiers', 'machine learning', 'computer science', 'root', 'support vector machine', 'supervised learning', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'support vector machine', 'supervised learning', 'machine learning', 'computer science', 'root', 'naive bayes classifiers', 'classifiers', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'naive bayes classifiers', 'classifiers', 'machine learning', 'computer science', 'root', 'face detection', 'face recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'face detection', 'face recognition', 'pattern recognition', 'machine learning', 'computer science', 'root', 'face detection', 'object recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'face detection', 'object recognition', 'pattern recognition', 'machine learning', 'computer science', 'root', 'recurrent neural networks', 'neural networks', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'recurrent neural networks', 'neural networks', 'machine learning', 'computer science', 'root', 'dimensionality reduction', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'dimensionality reduction', 'pattern recognition', 'machine learning', 'computer science', 'root', 'object detection', 'object recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'object detection', 'object recognition', 'pattern recognition', 'machine learning', 'computer science', 'root', 'unsupervised learning', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'unsupervised learning', 'machine learning', 'computer science', 'root', 'semi-supervised learning', 'weakly supervised learning', 'supervised learning', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'semi-supervised learning', 'weakly supervised learning', 'supervised learning', 'machine learning', 'computer science', 'root', 'variational auto-encoder', 'autoencoder', 'artificial neural network', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'variational auto-encoder', 'autoencoder', 'artificial neural network', 'machine learning', 'computer science', 'root', 'feature learning', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'feature learning', 'machine learning', 'computer science', 'root', 'convolutional neural network', 'feedforward neural network', 'neural networks', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'convolutional neural network', 'feedforward neural network', 'neural networks', 'machine learning', 'computer science', 'root', 'convolutional neural netw ...
# ['streaming video', 'videotex', 'video streaming', 'root']
# ['streaming video', 'videotex', 'video streaming', 'root']
# ['telecommunication systems', 'computer systems', 'computer science', 'root']
# ['data analytics', 'data mining', 'computer science', 'root']
# ['java virtual machines', 'java', 'high level languages', 'computer programming', 'computer science', 'root']
# ['supervised classification', 'image classification', 'imaging systems', 'root', 'supervised classification', 'image classification', 'image processing', 'computer imaging and vision', 'computer science', 'root', 'supervised classification', 'image classification', 'image processing', 'signal processing', 'root', 'supervised classification', 'image classification', 'classification', 'root']
# ['supervised classification', 'image classification', 'imaging systems', 'root']
# ['knowledge visualization', 'information visualization', 'interactive computer graphics', 'user interfaces', 'human computer interaction', 'computer science', 'root']
# ['streaming video', 'videotex', 'video streaming', 'root']
# ['decision trees', 'data mining', 'computer science', 'root']
# ['naive bayes classifiers', 'classifiers', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'naive bayes classifiers', 'classifiers', 'machine learning', 'computer science', 'root']
# ['filesystem', 'operating systems', 'computer science', 'root']
# ['real time systems', 'knowledge based systems', 'artificial intelligence', 'computer science', 'root']
# ['software development methods', 'software development', 'software project', 'software design', 'software engineering', 'computer science', 'root']
# ['mobile application development', 'software development', 'software project', 'software design', 'software engineering', 'computer science', 'root', 'software development methods', 'software development', 'software project', 'software design', 'software engineering', 'computer science', 'root', 'video game development', 'software development', 'software project', 'software design', 'software engineering', 'computer science', 'root']
# ['continuous speech recognition', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'continuous speech recognition', 'computational linguistics', 'computer science', 'root']
# ['relation extraction', 'information extraction', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'relation extraction', 'information extraction', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'question answering', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'question answering', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'natural language generation', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'natural language generation', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'continuous speech recognition', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'continuous speech recognition', 'computational linguistics', 'computer science', 'root', 'dependency parser', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'dependency parser', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'machine translation systems', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'machine translation systems', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'opinion mining', 'sentiment analysis', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'opinion mining', 'sentiment analysis', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'text classification', 'text processing', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'text classification', 'text processing', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'natural language understanding', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'natural language understanding', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'speech recognition', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'speech recognition', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'speech recognition', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'speech recognition', 'computational linguistics', 'computer science', 'root', 'neural machine translation', 'statistical machine translation', 'machine translation', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'neural machine translation', 'statistical machine translation', 'machine translation', 'computational linguistics', 'computer science', 'root', 'Topic modeling', 'text mining', 'text processing', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'Topic modeling', 'text mining', 'text processing', 'natural language processing', 'computational linguistics', 'computer science', 'root']
# ['image search', 'search engines', 'root']
# ['image search', 'search engines', 'root', 'web crawlers', 'search engines', 'root']
# ['dependency parser', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'dependency parser', 'natural language processing', 'computer science', 'root', 'dependency parser', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'dependency parser', 'natural language processing', 'computational linguistics', 'computer science', 'root']
# ['ambient intelligence', 'artificial intelligence', 'computer science', 'root']
# ['augmented reality systems', 'augmented reality', 'virtual reality', 'human computer interaction', 'computer science', 'root', 'augmented reality systems', 'augmented reality', 'virtual reality', 'simulation', 'root']
# ...
# ['database administration', 'system administration', 'systems management', 'information technology management', 'root']
# ['audio player software', 'media player software', 'multimedia software', 'application', 'software', 'computer science', 'root']
# ['audio player software', 'media player software', 'multimedia software', 'application', 'software', 'computer science', 'root']
# ['audio player software', 'media player software', 'multimedia software', 'application', 'software', 'computer science', 'root']
# ['electronic trading platform', 'application', 'software', 'computer science', 'root']
# ['static site generator', 'web framework', 'software framework', 'computing platform', 'root', 'static site generator', 'web framework', 'software framework', 'software library', 'programming tool', 'utility software', 'system software', 'software', 'computer science', 'root', 'static site generator', 'web framework', 'software framework', 'software library', 'programming tool', 'utility software', 'computer program', 'program', 'software', 'computer science', 'root', 'static site generator', 'web framework', 'software framework', 'software library', 'software component', 'root', 'static site generator', 'web framework', 'software framework', 'computer program', 'program', 'software', 'computer science', 'root', 'static site generator', 'web framework', 'software framework', 'computing infrastructure', 'root', 'static site generator', 'web template system', 'desktop publishing software', 'editor', 'application', 'software', 'computer science', 'root', 'static site generator', 'web template system', 'desktop publishing software', 'editor', 'interactive computing', 'software', 'computer science', 'root', 'static site generator', 'web template system', 'desktop publishing software', 'publishing software', 'software', 'computer science', 'root', 'static site generator', 'web template system', 'desktop publishing software', 'graphics software', 'computer program', 'program', 'software', 'computer science', 'root', 'static site generator', 'web template system', 'desktop publishing software', 'graphics software', 'application', 'software', 'computer science', 'root', 'static site generator', 'web template system', 'desktop publishing software', 'graphics software', 'editor', 'application', 'software', 'computer science', 'root', 'static site generator', 'web template system', 'desktop publishing software', 'graphics software', 'editor', 'interactive computing', 'software', 'computer science', 'root']
# ['static site generator', 'web framework', 'software framework', 'computing platform', 'root', 'static site generator', 'web framework', 'software framework', 'software library', 'programming tool', 'utility software', 'system software', 'software', 'computer science', 'root', 'static site generator', 'web framework', 'software framework', 'software library', 'programming tool', 'utility software', 'computer program', 'program', 'software', 'computer science', 'root', 'static site generator', 'web framework', 'software framework', 'software library', 'software component', 'root', 'static site generator', 'web framework', 'software framework', 'computer program', 'program', 'software', 'computer science', 'root', 'static site generator', 'web framework', 'software framework', 'computing infrastructure', 'root']
# ['static site generator', 'web template system', 'desktop publishing software', 'editor', 'application', 'software', 'computer science', 'root', 'static site generator', 'web template system', 'desktop publishing software', 'editor', 'interactive computing', 'software', 'computer science', 'root', 'static site generator', 'web template system', 'desktop publishing software', 'publishing software', 'software', 'computer science', 'root', 'static site generator', 'web template system', 'desktop publishing software', 'graphics software', 'computer program', 'program', 'software', 'computer science', 'root', 'static site generator', 'web template system', 'desktop publishing software', 'graphics software', 'application', 'software', 'computer science', 'root', 'static site generator', 'web template system', 'desktop publishing software', 'graphics software', 'editor', 'application', 'software', 'computer science', 'root', 'static site generator', 'web template system', 'desktop publishing software', 'graphics software', 'editor', 'interactive computing', 'software', 'computer science', 'root']
# ['static site generator', 'web template system', 'desktop publishing software', 'editor', 'application', 'software', 'computer science', 'root', 'static site generator', 'web template system', 'desktop publishing software', 'editor', 'interactive computing', 'software', 'computer science', 'root', 'static site generator', 'web template system', 'desktop publishing software', 'publishing software', 'software', 'computer science', 'root', 'static site generator', 'web template system', 'desktop publishing software', 'graphics software', 'computer program', 'program', 'software', 'computer science', 'root', 'static site generator', 'web template system', 'desktop publishing software', 'graphics software', 'application', 'software', 'computer science', 'root', 'static site generator', 'web template system', 'desktop publishing software', 'graphics software', 'editor', 'application', 'software', 'computer science', 'root', 'static site generator', 'web template system', 'desktop publishing software', 'graphics software', 'editor', 'interactive computing', 'software', 'computer science', 'root']
# ['static site generator', 'web template system', 'desktop publishing software', 'publishing software', 'software', 'computer science', 'root']
# ['graphical user interface', 'system software', 'software', 'computer science', 'root', 'graphical user interface', 'user interface', 'root']
# ['video game', 'entertainment software', 'software', 'computer science', 'root']
# ['video game', 'application', 'software', 'computer science', 'root', 'video game', 'electronic game', 'game', 'root', 'video game', 'entertainment software', 'software', 'computer science', 'root']
# ['video game', 'electronic game', 'game', 'root']
# ['object-oriented programming', 'structured programming', 'programming paradigm', 'root']
# ['object-oriented programming', 'structured programming', 'programming paradigm', 'root']
# ['naive Bayes classifier', 'Bayes classifier', 'root']
# ['naive Bayes classifier', 'Bayes classifier', 'root']
# ['chatbot', 'software agent', 'computer program', 'program', 'software', 'computer science', 'root', 'chatbot', 'software agent', 'artificially intelligent entity', 'agent', 'root']
# ['chatbot', 'software agent', 'computer program', 'program', 'software', 'computer science', 'root', 'chatbot', 'software agent', 'artificially intelligent entity', 'agent', 'root']
# ['package management system', 'management system', 'root', 'package management system', 'digital distribution platform', 'online database', 'website', 'digital media', 'root', 'package management system', 'digital distribution platform', 'online database', 'website', 'software', 'computer science', 'root', 'package management system', 'digital distribution platform', 'online database', 'website', 'online service', 'service on Internet', 'e-service', 'root', 'package management system', 'digital distribution platform', 'online database', 'website', 'online service', 'service on Internet', 'network service', 'middleware of distributed system', 'middleware', 'system software', 'software', 'computer science', 'root', 'package management system', 'digital distribution platform', 'online database', 'online service', 'service on Internet', 'e-service', 'root', 'package management system', 'digital distribution platform', 'online database', 'online service', 'service on Internet', 'network service', 'middleware of distributed system', 'middleware', 'system software', 'software', 'computer science', 'root', 'package management system', 'digital distribution platform', 'online database', 'database', 'root', 'package management system', 'digital distribution platform', 'file hosting service', 'root', 'package management system', 'software', 'computer science', 'root']
# ['package management system', 'digital distribution platform', 'online database', 'website', 'digital media', 'root', 'package management system', 'digital distribution platform', 'online database', 'website', 'software', 'computer science', 'root', 'package management system', 'digital distribution platform', 'online database', 'website', 'online service', 'service on Internet', 'e-service', 'root', 'package management system', 'digital distribution platform', 'online database', 'website', 'online service', 'service on Internet', 'network service', 'middleware of distributed system', 'middleware', 'system software', 'software', 'computer science', 'root', 'package management system', 'digital distribution platform', 'online database', 'online service', 'service on Internet', 'e-service', 'root', 'package management system', 'digital distribution platform', 'online database', 'online service', 'service on Internet', 'network service', 'middleware of distributed system', 'middleware', 'system software', 'software', 'computer science', 'root', 'package management system', 'digital distribution platform', 'online database', 'database', 'root']
# ['package management system', 'digital distribution platform', 'online database', 'website', 'digital media', 'root', 'package management system', 'digital distribution platform', 'online database', 'website', 'software', 'computer science', 'root', 'package management system', 'digital distribution platform', 'online database', 'website', 'online service', 'service on Internet', 'e-service', 'root', 'package management system', 'digital distribution platform', 'online database', 'website', 'online service', 'service on Internet', 'network service', 'middleware of distributed system', 'middleware', 'system software', 'software', 'computer science', 'root', 'package management system', 'digital distribution platform', 'online database', 'online service', 'service on Internet', 'e-service', 'root', 'package management system', 'digital distribution platform', 'online database', 'online service', 'service on Internet', 'network service', 'middleware of distributed system', 'middleware', 'system software', 'software', 'computer science', 'root', 'package management system', 'digital distribution platform', 'online database', 'database', 'root', 'package management system', 'digital distribution platform', 'file hosting service', 'root']
# ['package management system', 'digital distribution platform', 'file hosting service', 'root']
# ['unit testing', 'software testing', 'product testing', 'test', 'root', 'unit testing', 'software testing', 'test', 'root']
# ['operating system', 'system software', 'software', 'computer science', 'root', 'operating system', 'computing platform', 'root']
# ['telecommunications application', 'application', 'software', 'computer science', 'root']
# ['medical imaging', 'medical diagnosis', 'root']
# ['medical imaging', 'medical diagnosis', 'root']
# ['Topic modeling', 'text mining', 'text processing', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'Topic modeling', 'text mining', 'text processing', 'natural language processing', 'computer science', 'root', 'Topic modeling', 'text mining', 'text processing', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'Topic modeling', 'text mining', 'text processing', 'natural language processing', 'computational linguistics', 'computer science', 'root']
# ['continuous integration', 'computing platform', 'root']
# ['kernel', 'operating system component', 'software component', 'root']
# ['distributed database', 'database', 'root']
# ['network security', 'computer networks', 'computer science', 'root', 'network security', 'computer security', 'computer science', 'root', 'network security', 'computer security', 'information security', 'security', 'root', 'network security', 'computer security', 'security', 'root', 'iot', 'architecture types', 'software architecture', 'software design', 'software engineering', 'computer science', 'root', 'iot', 'architecture types', 'software architecture', 'software engineering', 'computer science', 'root', 'iot', 'architecture types', 'software architecture', 'systems architecture', 'root', 'optical character recognition', 'character recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'optical character recognition', 'character recognition', 'pattern recognition', 'machine learning', 'computer science', 'root', 'optical character recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'optical character recognition', 'pattern recognition', 'machine learning', 'computer science', 'root', 'parallel processing systems', 'distributed systems', 'distributed computer systems', 'computer systems', 'computer science', 'root', 'relation extraction', 'information extraction', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'relation extraction', 'information extraction', 'natural language processing', 'computer science', 'root', 'relation extraction', 'information extraction', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'relation extraction', 'information extraction', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'relation extraction', 'information extraction', 'information retrieval', 'computer science', 'root', 'theoretical computer science', 'computer science', 'root', 'emotion recognition', 'face recognition', 'pattern recognition', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'emotion recognition', 'face recognition', 'pattern recognition', 'machine learning', 'computer science', 'root', 'emotion recognition', 'recognition', 'root', 'data clustering', 'cluster analysis', 'machine learning', 'artificial intelligence', 'computer science', 'root', 'data clustering', 'cluster analysis', 'machine learning', 'computer science', 'root', 'data clustering', 'cluster analysis', 'data analysis', 'root', 'data clustering', 'cluster analysis', 'data mining', 'computer science', 'root', 'three dimensional computer graphics', 'computer imaging and vision', 'computer science', 'root', 'unscented kalman filter', 'kalman filters', 'signal processing', 'root', 'question answering', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'question answering', 'natural language processing', 'computer science', 'root', 'question answering', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'question answering', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'question answering', 'computer program', 'program', 'software', 'computer science', 'root', 'question answering', 'natural-language user interface', 'voice user interface', 'user interface', 'root', 'natural language generation', 'natural language processing', 'artificial intelligence', 'computer science', 'root', 'natural language generation', 'natural language processing', 'computer science', 'root', 'natural language generation', 'natural language processing', 'computational linguistics', 'database systems', 'computer systems', 'computer science', 'root', 'natural language generation', 'natural language processing', 'computational linguistics', 'computer science', 'root', 'program debugging', 'software quality', 'software design', 'software e ...

# %%
removed_nodes
# Out:
# ['videotex',
#  'video streaming',
#  'streaming video',
#  'image search',
#  'search engines',
#  'bibliographic retrieval systems',
#  'digital libraries',
#  'web crawlers',
#  'cloud services',
#  'risk management tool',
#  'management tool',
#  'knowledge organization system',
#  'reference work',
#  'linear model',
#  'regression model',
#  'payment system',
#  'financial system',
#  'malware analysis',
#  'reverse engineering',
#  'interface standard',
#  'communication system',
#  'data synchronization',
#  'data management',
#  'database administration',
#  'system administration',
#  'systems management',
#  'naive Bayes classifier',
#  'Bayes classifier']
